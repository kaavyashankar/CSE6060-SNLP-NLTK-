# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
doc = nlp('I am happy to write this letter of recommendation for AAA who intends to pursue a Masters degree at your prestigious university. I have known him only for the past year and it was easy to observe that he is a quick learner and hardworking. I handled the course Natural Language Processing for him during his sixth semester.  ')


print([(X.text, X.label_) for X in doc.ents])
# Out:
# [('AAA', 'ORG'), ('the past year', 'DATE'), ('his sixth semester', 'DATE')]

# %%
print([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [(I, 'O', ''), (am, 'O', ''), (happy, 'O', ''), (to, 'O', ''), (write, 'O', ''), (this, 'O', ''), (letter, 'O', ''), (of, 'O', ''), (recommendation, 'O', ''), (for, 'O', ''), (AAA, 'B', 'ORG'), (who, 'O', ''), (intends, 'O', ''), (to, 'O', ''), (pursue, 'O', ''), (a, 'O', ''), (Masters, 'O', ''), (degree, 'O', ''), (at, 'O', ''), (your, 'O', ''), (prestigious, 'O', ''), (university, 'O', ''), (., 'O', ''), (I, 'O', ''), (have, 'O', ''), (known, 'O', ''), (him, 'O', ''), (only, 'O', ''), (for, 'O', ''), (the, 'B', 'DATE'), (past, 'I', 'DATE'), (year, 'I', 'DATE'), (and, 'O', ''), (it, 'O', ''), (was, 'O', ''), (easy, 'O', ''), (to, 'O', ''), (observe, 'O', ''), (that, 'O', ''), (he, 'O', ''), (is, 'O', ''), (a, 'O', ''), (quick, 'O', ''), (learner, 'O', ''), (and, 'O', ''), (hardworking, 'O', ''), (., 'O', ''), (I, 'O', ''), (handled, 'O', ''), (the, 'O', ''), (course, 'O', ''), (Natural, 'O', ''), (Language, 'O', ''), (Processing, 'O', ''), (for, 'O', ''), (him, 'O', ''), (during, 'O', ''), (his, 'B', 'DATE'), (sixth, 'I', 'DATE'), (semester, 'I', 'DATE'), (., 'O', ''), ( , 'O', '')]

# %%
len(doc.ents)
# Out:
# 3

# %%
labels = [x.label_ for x in doc.ents]
Counter(labels)
# Out:
# Counter({'ORG': 1, 'DATE': 2})

# %%
sentences = [x for x in doc.sents]
print(sentences)
# Out:
# [I am happy to write this letter of recommendation for AAA who intends to pursue a Masters degree at your prestigious university., I have known him only for the past year and it was easy to observe that he is a quick learner and hardworking., I handled the course Natural Language Processing for him during his sixth semester.  ]

# %%
displacy.render(nlp(str(sentences)), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">[I am happy to write this letter of recommendation for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AAA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  who intends to pursue a Masters degree at your prestigious university., I have known him only for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and it was easy to observe that he is a quick learner and hardworking., I handled the course Natural Language Processing for him during
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     his sixth semester
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .  ]</div></span>

# %%
for token in doc:
    print(token, token.idx)
# Out:
# I 0
# am 2
# happy 5
# to 11
# write 14
# this 20
# letter 25
# of 32
# recommendation 35
# for 50
# AAA 54
# who 58
# intends 62
# to 70
# pursue 73
# a 80
# Masters 82
# degree 90
# at 97
# your 100
# prestigious 105
# university 117
# . 127
# I 129
# have 131
# known 136
# him 142
# only 146
# for 151
# the 155
# past 159
# year 164
# and 169
# it 173
# was 176
# easy 180
# to 185
# observe 188
# that 196
# he 201
# is 204
# a 207
# quick 209
# learner 215
# and 223
# hardworking 227
# . 238
# I 240
# handled 242
# the 250
# course 254
# Natural 261
# Language 269
# Processing 278
# for 289
# him 293
# during 297
# his 304
# sixth 308
# semester 314
# . 322
#   324

# %%
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="da2804bfbacc4559b8a780bc637f889f-0" class="displacy" width="10375" height="1012.0" direction="ltr" style="max-width: none; height: 1012.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">am</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">happy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">write</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">letter</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">recommendation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">AAA</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">who</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">intends</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">pursue</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">Masters</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">degree</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">your</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">prestigious</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">university.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">known</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">him</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">only</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">past</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">year</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5300">N

# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html5lib')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

# %%
#IMPORTING FROM WEB

ny_bb = url_to_string('https://www.studentnewsdaily.com/archive/daily-news-article/')

# %%
article = nlp(ny_bb)
len(article.ents)
# Out:
# 1509

# %%
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'ORG': 551,
#          'WORK_OF_ART': 23,
#          'DATE': 283,
#          'CARDINAL': 143,
#          'PERSON': 54,
#          'GPE': 259,
#          'NORP': 63,
#          'ORDINAL': 23,
#          'FAC': 10,
#          'EVENT': 11,
#          'LOC': 19,
#          'PERCENT': 2,
#          'MONEY': 43,
#          'TIME': 6,
#          'PRODUCT': 10,
#          'QUANTITY': 8,
#          'LAW': 1})

# %%
items = [x.text for x in article.ents]
Counter(items).most_common(3)
# Out:
# [('Reuters', 66), ('U.S.', 36), ('New York Post', 35)]

# %%
sentences = [x for x in article.sents]
print(sentences[10])
# Out:
# Questions relating to the week's Daily News Articles                                                     keyboard_arrow_right

# %%
displacy.render(nlp(str(sentences)), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">[         Daily News Article                                                                                                                                                                                         ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Student News Daily                                                                       Archives
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#                                                                                                 ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Daily News
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Article                     Posted every weekday
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     keyboard_arrow_right
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#                                                                                        ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# 's
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World Events
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  articles every
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#                                                      ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     keyboard_arrow_right
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#                                                                                        ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# 's Example of Media Bias                     ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Weekly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  example of biased reporting                                                     keyboard_arrow_right                                                                                       ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# 's Editorial                     Weekly opinion article from the web                                                     keyboard_arrow_right                                                                                       ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# 's
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     News Quiz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Questions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  relating to the
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# 's
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Daily News
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Articles
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     keyboard_arrow_right
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#                                                                                        ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# 's Editorial Cartoon                     , Cartoon is accompanied by a question                                                     keyboard_arrow_right                                                                                       Extras!                     ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Videos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius

# %%
displacy.render(nlp(str(sentences[20])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="507cb9f2c97949948c6a32ed6f4ea9a4-0" class="displacy" width="890" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Journalist</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Code</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">Ethics</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">                                                    </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">keyboard_arrow_right</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">                                                                                      </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">SPACE</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-507cb9f2c97949948c6a32ed6f4ea9a4-0-0" stroke-width="2px" d="M70,122.0 C70,62.0 165.0,62.0 165.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-507cb9f2c97949948c6a32ed6f4ea9a4-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,124.0 L62,112.0 78,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-507cb9f2c97949948c6a32ed6f4ea9a4-0-1" stroke-width="2px" d="M190,122.0 C190,62.0 285.0,62.0 285.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-507cb9f2c97949948c6a32ed6f4ea9a4-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M285.0,124.0 L293.0,112.0 277.0,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-507cb9f2c97949948c6a32ed6f4ea9a4-0-2" stroke-width="2px" d="M310,122.0 C310,62.0 405.0,62.0 405.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-507cb9f2c97949948c6a32ed6f4ea9a4-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M405.0,124.0 L413.0,112.0 397.0,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-507cb9f2c97949948c6a32ed6f4ea9a4-0-3" stroke-width="2px" d="M430,122.0 C430,62.0 525.0,62.0 525.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-507cb9f2c97949948c6a32ed6f4ea9a4-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle"></textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M525.0,124.0 L533.0,112.0 517.0,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-507cb9f2c97949948c6a32ed6f4ea9a4-0-4" stroke-width="2px" d="M190,122.0 C190,2.0 650.0,2.0 650.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-507cb9f2c97949948c6a32ed6f4ea9a4-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M650.0,124.0 L658.0,112.0 642.0,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-507cb9f2c97949948c6a32ed6f4ea9a4-0-5" stroke-width="2px" d="M670,122.0 C670,62.0 765.0,62.0 765.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-507cb9f2c97949948c6a32ed6f4ea9a4-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle"></textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M765.0,124.0 L773.0,112.0 757.0,112.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
 print("TEXT	START	END	LABEL	DESCRIPTION")
for ent in article.ents:
    print('\n',ent.text,'\t',ent.start_char,'\t', ent.end_char,'\t', ent.label_)
# Out:
# TEXT	START	END	LABEL	DESCRIPTION
#
#  Student News Daily                                                                       Archives                                                                                                 	 212 	 405 	 ORG
#
#  Daily News 	 405 	 415 	 WORK_OF_ART
#
#  keyboard_arrow_right 	 517 	 537 	 ORG
#
#  Tuesday 	 624 	 631 	 DATE
#
#  Three 	 667 	 672 	 CARDINAL
#
#  Tuesday 	 688 	 695 	 DATE
#
#  keyboard_arrow_right 	 748 	 768 	 ORG
#
#  Wednesday 	 855 	 864 	 DATE
#
#  Media Bias 	 878 	 888 	 ORG
#
#  Thursday 	 1103 	 1111 	 DATE
#
#  Friday 	 1339 	 1345 	 DATE
#
#  week 	 1404 	 1408 	 DATE
#
#  Daily News 	 1411 	 1421 	 ORG
#
#  Friday 	 1590 	 1596 	 DATE
#
#  Editorial Cartoon                      	 1599 	 1637 	 ORG
#
#  Human Interest News 	 1877 	 1896 	 ORG
#
#  keyboard_arrow_right 	 1949 	 1969 	 CARDINAL
#
#  Liberal Beliefs 	 2390 	 2405 	 PERSON
#
#  Media Bias 	 2941 	 2951 	 ORG
#
#  keyboard_arrow_right 	 3189 	 3209 	 CARDINAL
#
#  keyboard_arrow_right 	 3545 	 3565 	 ORG
#
#  keyboard_arrow_right 	 3718 	 3738 	 ORG
#
#  keyboard_arrow_right 	 4557 	 4577 	 ORG
#
#  keyboard_arrow_right 	 4895 	 4915 	 ORG
#
#  keyboard_arrow_right 	 5061 	 5081 	 CARDINAL
#
#  Resources 	 5570 	 5579 	 WORK_OF_ART
#
#  daily 	 5726 	 5731 	 DATE
#
#  May 2020 	 6085 	 6093 	 DATE
#
#  China 	 6374 	 6379 	 GPE
#
#  NASA 	 6400 	 6404 	 ORG
#
#  ABC 	 6428 	 6431 	 ORG
#
#  40/29 	 6438 	 6443 	 CARDINAL
#
#  News and 	 6444 	 6452 	 ORG
#
#  NY Times 	 6453 	 6461 	 ORG
#
#  5/7/2020 	 6589 	 6597 	 CARDINAL
#
#  Democratic 	 6625 	 6635 	 NORP
#
#  CBS News 	 6659 	 6667 	 ORG
#
#  April 2020 	 6732 	 6742 	 DATE
#
#  4/30/2020 - 2nd 	 6805 	 6820 	 DATE
#
#  US Navy Ship Conducts Freedom of Navigation Operation 	 6821 	 6874 	 WORK_OF_ART
#
#  China 	 6876 	 6881 	 GPE
#
#  Angry - Compiled 	 6882 	 6898 	 ORG
#
#  USNI News 	 6904 	 6913 	 ORG
#
#  DHS 	 7069 	 7072 	 ORG
#
#  New York Post 	 7135 	 7148 	 ORG
#
#  4/20/2020 	 7276 	 7285 	 DATE
#
#  China 	 7288 	 7293 	 GPE
#
#  Hong Kong 	 7302 	 7311 	 GPE
#
#  New York Post 	 7338 	 7351 	 ORG
#
#  4/16/2020 	 7479 	 7488 	 DATE
#
#  Jackie Robinson Day 	 7506 	 7525 	 PERSON
#
#  April 15 	 7540 	 7548 	 DATE
#
#  4/13/2020 	 7681 	 7690 	 DATE
#
#  50th 	 7744 	 7748 	 ORDINAL
#
#  CNET 	 7777 	 7781 	 ORG
#
#  CNN 	 7786 	 7789 	 ORG
#
#  4/9/2020 	 7917 	 7925 	 DATE
#
#  Pfizer 	 7928 	 7934 	 FAC
#
#  NY Post 	 8003 	 8010 	 ORG
#
#  WSJ 	 8015 	 8018 	 ORG
#
#  U.S. 	 8157 	 8161 	 GPE
#
#  Fox News 	 8272 	 8280 	 ORG
#
#  UPI 	 8282 	 8285 	 ORG
#
#  WhiteHouse.gov 	 8290 	 8304 	 ORG
#
#  U.S. Intelligence 	 8482 	 8499 	 ORG
#
#  Bloomberg News 	 8507 	 8521 	 ORG
#
#  March 2020 	 8586 	 8596 	 DATE
#
#  Vietnam War Veterans 	 8684 	 8704 	 EVENT
#
#  2020 	 8708 	 8712 	 DATE
#
#  3/27/2020 	 8869 	 8878 	 DATE
#
#  Birx 	 8885 	 8889 	 PERSON
#
#  Fauci 	 8898 	 8903 	 PERSON
#
#  3/26/2020 	 9060 	 9069 	 DATE
#
#  White House 	 9072 	 9083 	 ORG
#
#  Monday Night Football 	 9111 	 9132 	 WORK_OF_ART
#
#  New York Post 	 9143 	 9156 	 ORG
#
#  3/25/2020 - LA Times 	 9284 	 9304 	 ORG
#
#  Bloomberg News 	 9309 	 9323 	 ORG
#
#  N95 	 9347 	 9350 	 ORG
#
#  Obama - Washington Examiner 	 9376 	 9403 	 ORG
#
#  DEA 	 9551 	 9554 	 ORG
#
#  San Diego 	 9604 	 9613 	 GPE
#
#  3/12/2020 - Trump 	 9741 	 9758 	 DATE
#
#  3/11/2020 	 9939 	 9948 	 DATE
#
#  17-year-olds 	 9956 	 9968 	 DATE
#
#  Colorado 	 9977 	 9985 	 GPE
#
#  1st 	 9988 	 9991 	 ORDINAL
#
#  20 years 	 10012 	 10020 	 DATE
#
#  Epoch Times 	 10037 	 10048 	 ORG
#
#  Colo. Comm 	 10053 	 10063 	 PERSON
#
#  3/10/2020 	 10198 	 10207 	 DATE
#
#  Saudi 	 10221 	 10226 	 NORP
#
#  one-day 	 10257 	 10264 	 DATE
#
#  mkt 	 10279 	 10282 	 ORG
#
#  30 years 	 10286 	 10294 	 DATE
#
#  3/9/2020 	 10428 	 10436 	 CARDINAL
#
#  Inside America 	 10476 	 10490 	 LOC
#
#  The New York Times 	 10508 	 10526 	 ORG
#
#  First Test of Experimental 	 10688 	 10714 	 ORG
#
#  The Wall Street Journal 	 10737 	 10760 	 ORG
#
#  3/5/2020 - Super 	 10888 	 10904 	 DATE
#
#  Tuesday 	 10905 	 10912 	 DATE
#
#  Biden 	 10925 	 10930 	 GPE
#
#  one 	 10939 	 10942 	 CARDINAL
#
#  one 	 10946 	 10949 	 CARDINAL
#
#  Sanders - Reuters 	 10965 	 10982 	 ORG
#
#  3/4/2020 - FBI 	 11110 	 11124 	 PERCENT
#
#  UPI 	 11189 	 11192 	 ORG
#
#  3/3/2020 - World #1 	 11320 	 11339 	 MONEY
#
#  Israeli 	 11342 	 11349 	 NORP
#
#  ‘weeks 	 11365 	 11371 	 DATE
#
#  New York Post 	 11405 	 11418 	 ORG
#
#  3/2/2020 - Biden 	 11546 	 11562 	 TIME
#
#  Super Tuesday 	 11573 	 11586 	 DATE
#
#  South Carolina 	 11608 	 11622 	 GPE
#
#  New York Post 	 11625 	 11638 	 ORG
#
#  February 2020 	 11703 	 11716 	 DATE
#
#  2/28/2020 	 11779 	 11788 	 DATE
#
#  NASA 	 11791 	 11795 	 ORG
#
#  Katherine Johnson - Science News 	 11801 	 11833 	 PERSON
#
#  2/27/2020 - New 	 11961 	 11976 	 DATE
#
#  DOJ 	 11977 	 11980 	 ORG
#
#  US 	 11995 	 11997 	 GPE
#
#  Fox News 	 12052 	 12060 	 ORG
#
#  2/26/2020 	 12188 	 12197 	 DATE
#
#  India 	 12200 	 12205 	 GPE
#
#  Trump - Politico 	 12235 	 12251 	 ORG
#
#  2/25/2020 	 12379 	 12388 	 DATE
#
#  Iran 	 12416 	 12420 	 GPE
#
#  1979 	 12455 	 12459 	 DATE
#
#  2/24/2020 - 40 years later 	 12609 	 12635 	 DATE
#
#  American 	 12696 	 12704 	 NORP
#
#  CBS Sports 	 12713 	 12723 	 ORG
#
#  2/21/2020 	 12851 	 12860 	 DATE
#
#  75th 	 12903 	 12907 	 ORDINAL
#
#  2/20/2020 - Bloomberg 	 13057 	 13078 	 DATE
#
#  2/19/2020 	 13276 	 13285 	 DATE
#
#  2/18/2020 	 13476 	 13485 	 DATE
#
#  China 	 13512 	 13517 	 GPE
#
#  Defense 	 13543 	 13550 	 ORG
#
#  UK Daily Mail 	 13583 	 13596 	 ORG
#
#  VOA News 	 13598 	 13606 	 ORG
#
#  Hill 	 13612 	 13616 	 FAC
#
#  CBSNews 	 13621 	 13628 	 PRODUCT
#
#  Abraham Lincoln 	 13768 	 13783 	 PERSON
#
#  The Great Emancipator 	 13786 	 13807 	 WORK_OF_ART
#
#  George Washington 	 13947 	 13964 	 PERSON
#
#  2/13/2020 	 14115 	 14124 	 DATE
#
#  Harvard 	 14162 	 14169 	 ORG
#
#  Yale 	 14171 	 14175 	 ORG
#
#  2/12/2020 - DOJ 	 14350 	 14365 	 DATE
#
#  New York Post 	 14424 	 14437 	 ORG
#
#  2/11/2020 - World # 	 14565 	 14584 	 DATE
#
#  Mexican 	 14588 	 14595 	 NORP
#
#  U.S. 	 14654 	 14658 	 GPE
#
#  The Wall Street Journal 	 14661 	 14684 	 ORG
#
#  2/10/2020 	 14812 	 14821 	 DATE
#
#  Naval Air Station Pensacola 	 14869 	 14896 	 ORG
#
#  U.S. - Compiled 	 14914 	 14929 	 ORG
#
#  CNN 	 14935 	 14938 	 ORG
#
#  NPR 	 14943 	 14946 	 ORG
#
#  Global Entry 	 15098 	 15110 	 ORG
#
#  New Yorkers 	 15123 	 15134 	 NORP
#
#  New York Post 	 15161 	 15174 	 ORG
#
#  2/6/2020 	 15302 	 15310 	 CARDINAL
#
#  2/5/2020 	 15539 	 15547 	 CARDINAL
#
#  Democrats 	 15557 	 15566 	 NORP
#
#  Iowa 	 15599 	 15603 	 GPE
#
#  New York Post 	 15613 	 15626 	 ORG
#
#  2/4/2020 - 2020 	 15754 	 15769 	 DATE
#
#  Trump 	 15790 	 15795 	 ORG
#
#  Hill 	 15827 	 15831 	 LOC
#
#  Des Moines Register 	 15970 	 15989 	 ORG
#
#  Dem 	 16018 	 16021 	 NORP
#
#  Iowa 	 16036 	 16040 	 GPE
#
#  New York Post 	 16052 	 16065 	 ORG
#
#  January 2020 	 16130 	 16142 	 DATE
#
#  1/31/2020 	 16205 	 16214 	 DATE
#
#  Southwest 	 16256 	 16265 	 LOC
#
#  New York Post 	 16275 	 16288 	 ORG
#
#  1/30/2020 	 16416 	 16425 	 DATE
#
#  Trump Mideast 	 16428 	 16441 	 LOC
#
#  Israeli 	 16461 	 16468 	 NORP
#
#  Palestinian 	 16495 	 16506 	 NORP
#
#  NBC News 	 16519 	 16527 	 ORG
#
#  1/29/2020 	 16655 	 16664 	 DATE
#
#  N.J. 	 16667 	 16671 	 GPE
#
#  1/28/2020 	 16872 	 16881 	 DATE
#
#  U.S. 	 16895 	 16899 	 GPE
#
#  The Epoch Times 	 16964 	 16979 	 ORG
#
#  1/27/2020 	 17107 	 17116 	 DATE
#
#  First 	 17133 	 17138 	 ORDINAL
#
#  U.S. 	 17139 	 17143 	 GPE
#
#  March 	 17164 	 17169 	 DATE
#
#  Life - BBC News 	 17174 	 17189 	 ORG
#
#  1/24/2020 	 17317 	 17326 	 DATE
#
#  UPI 	 17379 	 17382 	 ORG
#
#  1/23/2020 	 17510 	 17519 	 DATE
#
#  The Wall Street Journal 	 17576 	 17599 	 ORG
#
#  1/22/2020 	 17727 	 17736 	 DATE
#
#  Associated Press at Daily Telegraph 	 17797 	 17832 	 ORG
#
#  1/21/2020 	 17960 	 17969 	 DATE
#
#  #1 	 17978 	 17980 	 MONEY
#
#  POLAND 	 17981 	 17987 	 ORG
#
#  Holocaust 	 17990 	 17999 	 WORK_OF_ART
#
#  Poland 	 18020 	 18026 	 GPE
#
#  75th 	 18031 	 18035 	 ORDINAL
#
#  1/17/2020 	 18228 	 18237 	 DATE
#
#  Martin Luther King Jr. Day 2020 	 18240 	 18271 	 PERSON
#
#  1/16/2020 	 18399 	 18408 	 DATE
#
#  U.S. 	 18411 	 18415 	 GPE
#
#  UK 	 18437 	 18439 	 GPE
#
#  Huawei 	 18449 	 18455 	 ORG
#
#  Reuters 	 18467 	 18474 	 ORG
#
#  1/15/2020 	 18602 	 18611 	 DATE
#
#  US 	 18614 	 18616 	 GPE
#
#  21 	 18627 	 18629 	 CARDINAL
#
#  Saudis 	 18630 	 18636 	 NORP
#
#  Apple 	 18661 	 18666 	 ORG
#
#  BBC News 	 18710 	 18718 	 ORG
#
#  1/14/2020 	 18846 	 18855 	 DATE
#
#  Tsai Ing-wen 	 18869 	 18881 	 PERSON
#
#  Taiwan 	 18900 	 18906 	 GPE
#
#  New York Post 	 18931 	 18944 	 ORG
#
#  1/13/2020 - 2020 	 19072 	 19088 	 DATE
#
#  State 	 19102 	 19107 	 ORG
#
#  1/10/2020 	 19245 	 19254 	 DATE
#
#  Iran 	 19257 	 19261 	 GPE
#
#  Ukrainian 	 19269 	 19278 	 NORP
#
#  US 	 19289 	 19291 	 GPE
#
#  Canadian 	 19293 	 19301 	 NORP
#
#  Reuters 	 19318 	 19325 	 ORG
#
#  Trump 	 19474 	 19479 	 PERSON
#
#  Iran - WhiteHouse.gov 	 19507 	 19528 	 EVENT
#
#  Chinese 	 19674 	 19681 	 NORP
#
#  US Navy Base - 	 19722 	 19736 	 FAC
#
#  The Epoch Times 	 19737 	 19752 	 ORG
#
#  1/7/2020 - World #1 	 19880 	 19899 	 MONEY
#
#  Iran 	 19902 	 19906 	 GPE
#
#  The Daily Signal 	 19955 	 19971 	 ORG
#
#  Florida 	 20110 	 20117 	 GPE
#
#  first 	 20125 	 20130 	 ORDINAL
#
#  WFTS Tampa Bay 	 20186 	 20200 	 ORG
#
#  Fox News 	 20202 	 20210 	 ORG
#
#  WBUR 	 20215 	 20219 	 ORG
#
#  December 2019 	 20284 	 20297 	 DATE
#
#  2020 	 20399 	 20403 	 DATE
#
#  US 	 20565 	 20567 	 GPE
#
#  CNN 	 20602 	 20605 	 ORG
#
#  Belgium 	 20757 	 20764 	 GPE
#
#  75th 	 20766 	 20770 	 ORDINAL
#
#  Battle of the Bulge - UPI 	 20786 	 20811 	 WORK_OF_ART
#
#  Two 	 20952 	 20955 	 CARDINAL
#
#  Chinese 	 20956 	 20963 	 NORP
#
#  US 	 20988 	 20990 	 GPE
#
#  New York Post 	 21022 	 21035 	 ORG
#
#  Bush 	 21200 	 21204 	 PERSON
#
#  Obama 	 21209 	 21214 	 GPE
#
#  Afghan 	 21226 	 21232 	 NORP
#
#  New York Post 	 21250 	 21263 	 ORG
#
#  12/12/2019 	 21391 	 21401 	 CARDINAL
#
#  Forbes 	 21488 	 21494 	 PERSON
#
#  New Zealand 	 21866 	 21877 	 GPE
#
#  Reuters 	 21910 	 21917 	 ORG
#
#  Hawaii 	 22111 	 22117 	 GPE
#
#  12/4/2019 	 22489 	 22498 	 CARDINAL
#
#  12/3/2019 	 22711 	 22720 	 CARDINAL
#
#  NATO 	 22734 	 22738 	 ORG
#
#  70th 	 22741 	 22745 	 ORDINAL
#
#  CBD 	 22907 	 22910 	 ORG
#
#  FDA 	 22928 	 22931 	 ORG
#
#  New York Post 	 22977 	 22990 	 ORG
#
#  November 2019 	 23055 	 23068 	 DATE
#
#  11/22/2019 - Thanksgiving 2019 	 23131 	 23161 	 DATE
#  11/21/2019 	 23289 	 23299 	 DATE
#
#  US 	 23302 	 23304 	 GPE
#
#  Israeli 	 23310 	 23317 	 NORP
#
#  NPR 	 23379 	 23382 	 ORG
#
#  South Korea 	 23534 	 23545 	 GPE
#
#  UPI 	 23601 	 23604 	 ORG
#
#  11/18/2019 - US military academy athletes 	 23732 	 23773 	 MONEY
#
#  pro - Associated Press 	 23800 	 23822 	 ORG
#
#  Trump 	 23976 	 23981 	 ORG
#
#  Democrats 	 23989 	 23998 	 NORP
#
#  New York Post 	 24015 	 24028 	 ORG
#
#  The Washington Post 	 24267 	 24286 	 ORG
#
#  USS Grayback 	 24452 	 24464 	 FAC
#
#  75-year 	 24481 	 24488 	 DATE
#
#  UPI 	 24513 	 24516 	 ORG
#
#  ABC News 	 24521 	 24529 	 ORG
#
#  11/12/2019 	 24657 	 24667 	 CARDINAL
#
#  1 	 24677 	 24678 	 MONEY
#
#  China 	 24681 	 24686 	 GPE
#
#  11/8/2019 - 2019 Veterans Day 	 24847 	 24876 	 DATE
#
#  11/7/2019 - US 	 25004 	 25018 	 MONEY
#
#  YahooNews 	 25081 	 25090 	 ORG
#
#  Iranians 	 25448 	 25456 	 NORP
#
#  American 	 25466 	 25474 	 NORP
#
#  Ronald Reagan’s 	 25487 	 25502 	 PERSON
#
#  40 years ago 	 25520 	 25532 	 DATE
#
#  Associated Press 	 25535 	 25551 	 ORG
#
#  11/4/2019 	 25679 	 25688 	 CARDINAL
#
#  Green Beret 	 25691 	 25702 	 GPE
#
#  Medal of Honor 	 25711 	 25725 	 PERSON
#
#  first 	 25732 	 25737 	 ORDINAL
#
#  Fox News 	 25753 	 25761 	 ORG
#
#  11/1/2019 	 25889 	 25898 	 CARDINAL
#
#  Ronald Reagan 	 25917 	 25930 	 PERSON
#
#  Reuters 	 25968 	 25975 	 ORG
#
#  October 2019 	 26040 	 26052 	 DATE
#
#  Microsoft 	 26128 	 26137 	 ORG
#
#  Amazon 	 26148 	 26154 	 ORG
#
#  $10 billion 	 26159 	 26170 	 MONEY
#
#  Pentagon 	 26171 	 26179 	 ORG
#
#  Associated Press 	 26191 	 26207 	 ORG
#
#  NY Post 	 26211 	 26218 	 ORG
#
#  TikTok 	 26385 	 26391 	 PRODUCT
#
#  NY Post 	 26434 	 26441 	 ORG
#
#  Bloomberg 	 26443 	 26452 	 GPE
#
#  CBS 	 26454 	 26457 	 ORG
#
#  LA Times 	 26459 	 26467 	 ORG
#
#  Reuters 	 26469 	 26476 	 ORG
#
#  10/29/2019 - World #1 	 26604 	 26625 	 MONEY
#
#  U.S. 	 26628 	 26632 	 GPE
#
#  Cuban 	 26653 	 26658 	 NORP
#
#  Havana - CBS News 	 26673 	 26690 	 ORG
#
#  10/28/2019 - ISIS 	 26818 	 26835 	 DATE
#
#  U.S. 	 26875 	 26879 	 GPE
#
#  Syria - WhiteHouse.gov 	 26888 	 26910 	 GPE
#
#  first 	 27068 	 27073 	 ORDINAL
#
#  the Capitol - Compiled 	 27108 	 27130 	 FAC
#
#  CNN 	 27136 	 27139 	 ORG
#
#  USA Today 	 27141 	 27150 	 ORG
#
#  UK Daily Mail 	 27152 	 27165 	 ORG
#
#  CBS 	 27170 	 27173 	 ORG
#
#  less than 1 	 27336 	 27347 	 CARDINAL
#
#  UK Daily Mail 	 27383 	 27396 	 ORG
#
#  South Korean 	 27561 	 27573 	 NORP
#
#  CNN 	 27617 	 27620 	 ORG
#
#  Mexico 	 27772 	 27778 	 GPE
#
#  Reuters 	 27833 	 27840 	 ORG
#
#  Georgia 	 27981 	 27988 	 GPE
#
#  AJC, Marietta Daily Journal 	 28049 	 28076 	 ORG
#
#  Turkey 	 28220 	 28226 	 GPE
#
#  Trump Administration 	 28255 	 28275 	 ORG
#
#  UPI 	 28284 	 28287 	 ORG
#
#  15 	 28438 	 28440 	 MONEY
#
#  less hours 	 28465 	 28475 	 TIME
#
#  CNN Business 	 28497 	 28509 	 ORG
#
#  Democratic 	 28653 	 28663 	 NORP
#
#  4th 	 28678 	 28681 	 ORDINAL
#
#  UPI 	 28699 	 28702 	 ORG
#
#  Kurds 	 28854 	 28859 	 NORP
#
#  Syria 	 28877 	 28882 	 GPE
#
#  U.S. 	 28893 	 28897 	 GPE
#
#  Reuters 	 28917 	 28924 	 ORG
#
#  10/10/2019 - 800,000 	 29230 	 29250 	 CARDINAL
#
#  California 	 29294 	 29304 	 GPE
#
#  10/9/2019 	 29458 	 29467 	 CARDINAL
#
#  Nobel 	 29476 	 29481 	 WORK_OF_ART
#
#  oxygen - Los Angeles Times 	 29509 	 29535 	 ORG
#
#  10/8/2019 - World #1 	 29663 	 29683 	 MONEY
#
#  China 	 29685 	 29690 	 GPE
#
#  Houston 	 29696 	 29703 	 GPE
#
#  GM 	 29722 	 29724 	 ORG
#
#  WSJ 	 29754 	 29757 	 ORG
#
#  NY Post 	 29759 	 29766 	 ORG
#
#  10/7/2019 - 21-year-old 	 29894 	 29917 	 DATE
#
#  10 days 	 29967 	 29974 	 DATE
#
#  10/4/2019 	 30143 	 30152 	 CARDINAL
#
#  African Americans 	 30169 	 30186 	 NORP
#
#  non-African Americans - 	 30208 	 30231 	 NORP
#
#  The Detroit News 	 30232 	 30248 	 ORG
#
#  10/3/2019 - US to Collect DNA of All Undocumented Immigrants - AFP 	 30376 	 30442 	 MONEY
#
#  VOA 	 30446 	 30449 	 ORG
#
#  NBC News 	 30650 	 30658 	 ORG
#
#  10/1/2019 - World #1 	 30786 	 30806 	 EVENT
#
#  Communist 	 30809 	 30818 	 NORP
#
#  China 	 30819 	 30824 	 GPE
#
#  70th 	 30827 	 30831 	 ORDINAL
#
#  September 2019 	 30950 	 30964 	 DATE
#
#  Moon 	 31078 	 31082 	 PERSON
#
#  Mars 	 31087 	 31091 	 LOC
#
#  Fox News 	 31275 	 31283 	 ORG
#
#  9/26/2019 	 31411 	 31420 	 DATE
#
#  UN 	 31432 	 31434 	 ORG
#
#  U.N. 	 31711 	 31715 	 ORG
#
#  Nigerians 	 31890 	 31899 	 GPE
#
#  South Africa 	 31906 	 31918 	 GPE
#
#  ABC News 	 31939 	 31947 	 ORG
#
#  9/23/2019 	 32075 	 32084 	 FAC
#
#  American Airlines 	 32087 	 32104 	 ORG
#
#  Fox News 	 32159 	 32167 	 ORG
#
#  9/18/2019 - CA 	 32295 	 32309 	 DATE
#
#  later start to 	 32326 	 32340 	 DATE
#
#  13 	 32358 	 32360 	 CARDINAL
#
#  Sacramento 	 32361 	 32371 	 GPE
#
#  9/17/2019 - World #1 	 32499 	 32519 	 DATE
#
#  half 	 32546 	 32550 	 CARDINAL
#
#  Saudi 	 32554 	 32559 	 NORP
#
#  Reuters 	 32575 	 32582 	 ORG
#
#  9/16/2019 - Constitution Day 2019 	 32710 	 32743 	 DATE
#
#  US 	 33081 	 33083 	 GPE
#
#  Stars and Stripes and UPI 	 33118 	 33143 	 WORK_OF_ART
#
#  9/11/2019 - Feds 	 33271 	 33287 	 DATE
#
#  New York Post 	 33350 	 33363 	 ORG
#
#  9/10/2019 - World #1 	 33491 	 33511 	 MONEY
#
#  Hong Kong 	 33514 	 33523 	 GPE
#
#  Trump 	 33545 	 33550 	 ORG
#
#  UPI 	 33562 	 33565 	 ORG
#
#  about 9/11 	 33721 	 33731 	 CARDINAL
#
#  9/6/2019 - 9/11 	 33860 	 33875 	 DATE
#
#  Mohammed 	 33898 	 33906 	 PERSON
#
#  2021 	 33924 	 33928 	 DATE
#
#  New York Post 	 33931 	 33944 	 ORG
#
#  9/5/2019 	 34072 	 34080 	 CARDINAL
#
#  Bloomberg News 	 34137 	 34151 	 ORG
#
#  NBC 	 34335 	 34338 	 ORG
#
#  Today 	 34341 	 34346 	 DATE
#
#  May 2019 	 34411 	 34419 	 DATE
#
#  5/28/2019 	 34482 	 34491 	 QUANTITY
#
#  75th 	 34500 	 34504 	 ORDINAL
#
#  2019 	 34682 	 34686 	 DATE
#
#  5/23/2019 	 34834 	 34843 	 DATE
#
#  Chinese 	 34882 	 34889 	 NORP
#
#  CNN 	 34922 	 34925 	 ORG
#
#  5/22/2019 	 35053 	 35062 	 DATE
#
#  U.S. Air Force 	 35065 	 35079 	 ORG
#
#  Iran 	 35112 	 35116 	 GPE
#
#  North Korea 	 35118 	 35129 	 GPE
#
#  Elizabeth 	 35299 	 35308 	 PERSON
#
#  USA Today 	 35374 	 35383 	 ORG
#
#  CNBC 	 35384 	 35388 	 ORG
#
#  BBC News 	 35393 	 35401 	 ORG
#
#  5/20/2019 - U.S. 	 35529 	 35545 	 DATE
#
#  Middle East - UPI 	 35576 	 35593 	 LOC
#
#  5/17/2019 - Hundreds 	 35721 	 35741 	 CARDINAL
#
#  South Florida 	 35768 	 35781 	 LOC
#
#  weekly 	 35787 	 35793 	 DATE
#
#  Miami Herald 	 35802 	 35814 	 ORG
#
#  South Florida Sun Sentinel 	 35819 	 35845 	 ORG
#
#  San Francisco 	 35985 	 35998 	 GPE
#
#  Navajo Code Talker 	 36193 	 36211 	 ORG
#
#  Begaye Sr. 	 36220 	 36230 	 PERSON
#
#  97 	 36239 	 36241 	 CARDINAL
#
#  NY Daily News 	 36265 	 36278 	 ORG
#
#  5/14/2019 	 36406 	 36415 	 DATE
#
#  Ramadan 	 36475 	 36482 	 DATE
#
#  London 	 36485 	 36491 	 GPE
#
#  Daily Telegraph 	 36494 	 36509 	 ORG
#
#  5/13/2019 - U.S. 	 36637 	 36653 	 DATE
#
#  North Korean 	 36661 	 36673 	 NORP
#
#  UPI 	 36687 	 36690 	 ORG
#
#  5/10/2019 - U.S. 	 36818 	 36834 	 DATE
#
#  Japan 	 36836 	 36841 	 GPE
#
#  India 	 36843 	 36848 	 GPE
#
#  Philippines 	 36853 	 36864 	 GPE
#
#  Beijing 	 36875 	 36882 	 GPE
#
#  Stars and Stripes                                                                                                                                 	 36903 	 37048 	 WORK_OF_ART
#
#  Arctic 	 37072 	 37078 	 LOC
#
#  Russian 	 37093 	 37100 	 NORP
#
#  Chinese 	 37102 	 37109 	 NORP
#
#  5/8/2019 	 37273 	 37281 	 CARDINAL
#
#  U.S. 	 37284 	 37288 	 GPE
#
#  the Middle East 	 37313 	 37328 	 LOC
#
#  Iran 	 37340 	 37344 	 GPE
#
#  UPI 	 37355 	 37358 	 ORG
#
#  140,000 	 37508 	 37515 	 CARDINAL
#
#  Japan 	 37529 	 37534 	 GPE
#
#  Naruhito - Reuters 	 37549 	 37567 	 PERSON
#
#  5/6/2019 	 37695 	 37703 	 CARDINAL
#
#  Israel 	 37706 	 37712 	 GPE
#
#  600 	 37720 	 37723 	 CARDINAL
#
#  Gaza - Compiled 	 37737 	 37752 	 ORG
#
#  UPI 	 37758 	 37761 	 ORG
#
#  NY Post 	 37766 	 37773 	 ORG
#
#  U.S. 	 37912 	 37916 	 GPE
#
#  UPI 	 37956 	 37959 	 ORG
#
#  CNN 	 38159 	 38162 	 ORG
#
#  Venezuela 	 38301 	 38310 	 GPE
#
#  Maduro 	 38360 	 38366 	 GPE
#
#  UPI 	 38376 	 38379 	 ORG
#
#  April 2019 	 38444 	 38454 	 DATE
#
#  4/30/2019 - World 	 38517 	 38534 	 MONEY
#
#  Canada 	 38572 	 38578 	 GPE
#
#  Philippines - Compiled 	 38601 	 38623 	 ORG
#
#  CNN 	 38629 	 38632 	 ORG
#
#  Newsweek 	 38634 	 38642 	 ORG
#
#  The Canadian Press 	 38647 	 38665 	 ORG
#
#  4/29/2019 	 38793 	 38802 	 CARDINAL
#
#  CBD 	 38805 	 38808 	 ORG
#
#  NBC News 	 38862 	 38870 	 ORG
#
#  4/26/2019 - N.C. 	 38998 	 39014 	 DATE
#
#  UPI 	 39085 	 39088 	 ORG
#
#  4/25/2019 	 39216 	 39225 	 CARDINAL
#
#  two 	 39240 	 39243 	 CARDINAL
#
#  China 	 39286 	 39291 	 GPE
#
#  4/24/2019 	 39425 	 39434 	 CARDINAL
#
#  Maryland 	 39437 	 39445 	 GPE
#
#  Virginia 	 39452 	 39460 	 GPE
#
#  21 	 39487 	 39489 	 CARDINAL
#
#  4/23/2019 	 39640 	 39649 	 CARDINAL
#
#  Ukrainian 	 39663 	 39672 	 NORP
#
#  London 	 39726 	 39732 	 GPE
#
#  Daily Telegraph 	 39735 	 39750 	 ORG
#
#  4/22/2019 - U.S. 	 39878 	 39894 	 DATE
#
#  Marine 	 39910 	 39916 	 ORG
#
#  North Korea 	 39930 	 39941 	 GPE
#
#  Spain 	 39958 	 39963 	 GPE
#
#  The Washington Post 	 39966 	 39985 	 ORG
#
#  Reuters 	 39987 	 39994 	 ORG
#
#  AFP 	 39999 	 40002 	 ORG
#
#  Hill 	 40176 	 40180 	 ORG
#
#  Reuters 	 40380 	 40387 	 ORG
#
#  4/17/2019 - MLB 	 40515 	 40530 	 MONEY
#
#  Jackie Robinson Day 	 40542 	 40561 	 PERSON
#
#  year 	 40565 	 40569 	 DATE
#
#  100th 	 40577 	 40582 	 ORDINAL
#
#  AP 	 40594 	 40596 	 ORG
#
#  CBS News 	 40600 	 40608 	 ORG
#
#  4/16/2019 	 40736 	 40745 	 DATE
#
#  1 	 40755 	 40756 	 MONEY
#
#  FRANCE 	 40759 	 40765 	 GPE
#
#  Paris 	 40796 	 40801 	 GPE
#
#  Notre Dame Cathedral - Reuters 	 40803 	 40833 	 ORG
#
#  4/15/2019 	 40961 	 40970 	 CARDINAL
#
#  Supreme Court 	 40978 	 40991 	 ORG
#
#  Reuters 	 41026 	 41033 	 ORG
#
#  Amazon 	 41173 	 41179 	 ORG
#
#  Alexa 	 41205 	 41210 	 ORG
#
#  Bloomberg 	 41272 	 41281 	 GPE
#
#  CNBC 	 41283 	 41287 	 ORG
#
#  Fox News 	 41292 	 41300 	 ORG
#
#  4/11/2019 - Last 	 41428 	 41444 	 DATE
#
#  103 	 41477 	 41480 	 CARDINAL
#
#  13 	 41492 	 41494 	 CARDINAL
#
#  Reuters 	 41704 	 41711 	 ORG
#
#  US 	 41861 	 41863 	 GPE
#
#  Libya 	 41887 	 41892 	 GPE
#
#  Tripoli - CNBC 	 41916 	 41930 	 ORG
#
#  Calexico 	 42082 	 42090 	 GPE
#
#  Dallas 	 42105 	 42111 	 GPE
#
#  Fort Worth 	 42112 	 42122 	 GPE
#
#  4/5/2019 	 42250 	 42258 	 DATE
#
#  New Jersey 	 42316 	 42326 	 GPE
#
#  4/4/2019 	 42454 	 42462 	 CARDINAL
#
#  Sony 	 42465 	 42469 	 ORG
#
#  Illinois 	 42511 	 42519 	 GPE
#
#  U.S. Navy 	 42665 	 42674 	 ORG
#
#  AP 	 42709 	 42711 	 ORG
#
#  Navy Times 	 42715 	 42725 	 ORG
#
#  4/2/2019 	 42853 	 42861 	 CARDINAL
#
#  1 	 42871 	 42872 	 MONEY
#
#  Greenland 	 42875 	 42884 	 GPE
#
#  Navy 	 43114 	 43118 	 ORG
#
#  SEAL 	 43123 	 43127 	 ORG
#
#  March 2019 	 43246 	 43256 	 DATE
#
#  National Vietnam War 	 43331 	 43351 	 EVENT
#
#  Google 	 43529 	 43535 	 ORG
#
#  China 	 43587 	 43592 	 GPE
#
#  3/27/2019 	 43736 	 43745 	 CARDINAL
#
#  Sky News 	 43820 	 43828 	 ORG
#
#  BBC 	 43830 	 43833 	 ORG
#
#  Reuters 	 43842 	 43849 	 ORG
#
#  3/26/2019 - World #1 	 43977 	 43997 	 DATE
#
#  Russian 	 44000 	 44007 	 NORP
#
#  Venezuela 	 44040 	 44049 	 GPE
#
#  3/25/2019 	 44187 	 44196 	 CARDINAL
#
#  3/18/2019 - Spring Break 2019 	 44393 	 44422 	 DATE
#
#  NPR 	 44633 	 44636 	 ORG
#
#  US 	 44805 	 44807 	 GPE
#
#  UK Daily Mail 	 44880 	 44893 	 ORG
#
#  Telegraph 	 44898 	 44907 	 PRODUCT
#
#  ABC 	 45104 	 45107 	 ORG
#
#  Cleveland 	 45114 	 45123 	 GPE
#
#  Days-long 	 45274 	 45283 	 DATE
#
#  Venezuela 	 45296 	 45305 	 GPE
#
#  21 	 45317 	 45319 	 CARDINAL
#
#  The UK Guardian                                                                                                                                 	 45329 	 45472 	 ORG
#
#  3/11/2019 	 45472 	 45481 	 QUANTITY
#
#  over 2 years 	 45514 	 45526 	 DATE
#
#  NY Post 	 45570 	 45577 	 ORG
#
#  CNN 	 45582 	 45585 	 ORG
#
#  3/8/2019 	 45713 	 45721 	 CARDINAL
#
#  Philadelphia 	 45724 	 45736 	 GPE
#
#  U.S. 	 45751 	 45755 	 GPE
#  PhillyVoice 	 45800 	 45811 	 ORG
#
#  WSJ 	 45820 	 45823 	 ORG
#
#  Mexico 	 45998 	 46004 	 GPE
#
#  New York Post 	 46014 	 46027 	 ORG
#
#  El Paso Times 	 46032 	 46045 	 ORG
#
#  3/6/2019 	 46173 	 46181 	 CARDINAL
#
#  India 	 46230 	 46235 	 GPE
#
#  Turkey - UPI 	 46237 	 46249 	 ORG
#
#  3/5/2019 	 46377 	 46385 	 CARDINAL
#
#  1 	 46395 	 46396 	 MONEY
#
#  U.S. 	 46399 	 46403 	 GPE
#
#  THAAD missile 	 46412 	 46425 	 PRODUCT
#
#  Israel 	 46444 	 46450 	 GPE
#
#  3/4/2019 	 46588 	 46596 	 QUANTITY
#
#  CNN 	 46658 	 46661 	 ORG
#
#  Wire 	 46662 	 46666 	 LAW
#
#  UPI 	 46671 	 46674 	 ORG
#
#  3/1/2019 	 46802 	 46810 	 CARDINAL
#
#  North Korea 	 46830 	 46841 	 GPE
#
#  Fox News 	 46888 	 46896 	 ORG
#
#  February 2019 	 46961 	 46974 	 DATE
#
#  2/28/2019 	 47037 	 47046 	 DATE
#
#  Senate 	 47049 	 47055 	 ORG
#
#  Democrats 	 47056 	 47065 	 NORP
#
#  Born-Alive Abortion Survivors Protection Act - Fox News 	 47072 	 47127 	 ORG
#
#  2/27/2019 	 47255 	 47264 	 CARDINAL
#
#  US 	 47267 	 47269 	 GPE
#
#  Vietnam 	 47288 	 47295 	 GPE
#
#  New York Post 	 47304 	 47317 	 ORG
#
#  2/26/2019 - World #1 	 47445 	 47465 	 DATE
#
#  UPI 	 47520 	 47523 	 ORG
#
#  BBC 	 47525 	 47528 	 ORG
#
#  NY Post 	 47530 	 47537 	 ORG
#
#  WAMU 	 47539 	 47543 	 ORG
#
#  Reuters 	 47548 	 47555 	 ORG
#
#  2/25/2019 - FAA 	 47683 	 47698 	 DATE
#
#  Reuters 	 47747 	 47754 	 ORG
#
#  2/22/2019 - U.S. 	 47882 	 47898 	 DATE
#
#  Central America 	 47900 	 47915 	 LOC
#
#  Reuters 	 47964 	 47971 	 ORG
#
#  2/21/2019 	 48099 	 48108 	 DATE
#
#  16 	 48141 	 48143 	 CARDINAL
#
#  Oregon 	 48147 	 48153 	 GPE
#
#  Oregon Statesman Journal 	 48170 	 48194 	 ORG
#
#  WGNO 	 48205 	 48209 	 ORG
#
#  2/19/2019 	 48337 	 48346 	 CARDINAL
#
#  Iran 	 48360 	 48364 	 GPE
#
#  France 	 48416 	 48422 	 GPE
#
#  24 	 48423 	 48425 	 CARDINAL
#
#  George Washington 	 48565 	 48582 	 PERSON
#
#  2/15/2019 	 48733 	 48742 	 CARDINAL
#
#  US 	 48955 	 48957 	 GPE
#
#  Rebuke 	 48975 	 48981 	 GPE
#
#  Reuters 	 49007 	 49014 	 ORG
#
#  US News and Press TV 	 49016 	 49036 	 ORG
#
#  2/13/2019 	 49164 	 49173 	 MONEY
#
#  $77 billion 	 49193 	 49204 	 MONEY
#
#  Reuters 	 49231 	 49238 	 ORG
#
#  2/12/2019 	 49366 	 49375 	 CARDINAL
#
#  Thai 	 49389 	 49393 	 NORP
#
#  2/11/2019 	 49581 	 49590 	 CARDINAL
#
#  Indiana 	 49593 	 49600 	 GPE
#
#  UPI 	 49666 	 49669 	 ORG
#
#  2/8/2019 - US 	 49797 	 49810 	 MONEY
#
#  American 	 49847 	 49855 	 NORP
#
#  July 	 49867 	 49871 	 DATE
#
#  NASA 	 49873 	 49877 	 ORG
#
#  New York Post 	 49880 	 49893 	 ORG
#
#  2/7/2019 	 50021 	 50029 	 CARDINAL
#
#  marijuana - New York Post 	 50082 	 50107 	 ORG
#
#  2/6/2019 - 2019 	 50235 	 50250 	 DATE
#
#  the Union - Compiled 	 50260 	 50280 	 ORG
#
#  CNN 	 50286 	 50289 	 ORG
#
#  Bloomberg 	 50291 	 50300 	 PERSON
#
#  2/5/2019 	 50441 	 50449 	 CARDINAL
#
#  Iran 	 50463 	 50467 	 GPE
#
#  New York Post 	 50535 	 50548 	 ORG
#
#  2/1/2019 - CBP 	 50676 	 50690 	 MONEY
#
#  Arizona Border - NBC News 	 50727 	 50752 	 ORG
#
#  January 2019 	 50817 	 50829 	 DATE
#
#  1/31/2019 	 50892 	 50901 	 DATE
#
#  Midwest 	 50960 	 50967 	 LOC
#
#  USPS 	 50969 	 50973 	 ORG
#
#  AP 	 50993 	 50995 	 ORG
#
#  ABC 7 News 	 50999 	 51009 	 ORG
#
#  1/30/2019 	 51137 	 51146 	 DATE
#
#  Mexico 	 51196 	 51202 	 GPE
#
#  U.S. 	 51227 	 51231 	 GPE
#
#  CNN 	 51234 	 51237 	 ORG
#
#  1/29/2019 - World #1 	 51365 	 51385 	 DATE
#
#  Poland 	 51388 	 51394 	 GPE
#
#  Auschwitz on International Holocaust Remembrance Day - Compiled 	 51413 	 51476 	 ORG
#
#  EuroNews 	 51482 	 51490 	 ORG
#
#  NPR 	 51495 	 51498 	 ORG
#
#  1/28/2019 - 	 51626 	 51637 	 DATE
#
#  US 	 51653 	 51655 	 GPE
#
#  1953 	 51724 	 51728 	 DATE
#
#  1/25/2019 	 51871 	 51880 	 CARDINAL
#
#  U.S. 	 51883 	 51887 	 GPE
#
#  Venuzeula - UPI 	 51939 	 51954 	 ORG
#
#  1/24/2019 	 52082 	 52091 	 CARDINAL
#
#  Supreme Court 	 52094 	 52107 	 ORG
#
#  first 	 52123 	 52128 	 ORDINAL
#
#  decade 	 52150 	 52156 	 DATE
#
#  UPI 	 52159 	 52162 	 ORG
#
#  1/23/2019 	 52290 	 52299 	 DATE
#
#  Covington Catholic 	 52334 	 52352 	 ORG
#
#  Native American 	 52378 	 52393 	 NORP
#
#  #1 	 52557 	 52559 	 CARDINAL
#
#  Turkey 	 52561 	 52567 	 GPE
#
#  New York Knicks 	 52584 	 52599 	 GPE
#
#  Enes Kanter - Compiled 	 52607 	 52629 	 PERSON
#
#  WSJ 	 52635 	 52638 	 ORG
#
#  FoxNews 	 52643 	 52650 	 ORG
#
#  Martin Luther King Jr. Day 	 52790 	 52816 	 PERSON
#
#  Justice Department 	 52961 	 52979 	 ORG
#
#  AP 	 53041 	 53043 	 ORG
#
#  1/16/2019 - 2019 	 53171 	 53187 	 DATE
#
#  State 	 53201 	 53206 	 ORG
#
#  1/15/2019 - World #1 	 53344 	 53364 	 DATE
#
#  Lima 	 53376 	 53380 	 GPE
#
#  Venezuelan 	 53406 	 53416 	 NORP
#
#  UPI 	 53429 	 53432 	 ORG
#
#  1/14/2019 	 53560 	 53569 	 DATE
#
#  New York 	 53572 	 53580 	 GPE
#
#  marijuana - New York Post 	 53622 	 53647 	 ORG
#
#  December 2018 	 53712 	 53725 	 DATE
#
#  Jan. 14 	 53810 	 53817 	 DATE
#
#  ABC News 	 53856 	 53864 	 ORG
#
#  12/19/2018 - Merry Christmas 	 53992 	 54020 	 DATE
#
#  2019 	 54031 	 54035 	 DATE
#
#  12/18/2018 	 54164 	 54174 	 CARDINAL
#
#  Gandhi 	 54188 	 54194 	 PERSON
#
#  Ghana - BBC News 	 54213 	 54229 	 ORG
#
#  NY Post 	 54235 	 54242 	 ORG
#
#  US 	 54433 	 54435 	 GPE
#
#  Africa 	 54447 	 54453 	 LOC
#
#  Voice of America) 	 54461 	 54478 	 ORG
#
#  12/14/2018 - U.S. 	 54611 	 54628 	 DATE
#
#  U.N. 	 54636 	 54640 	 ORG
#
#  Iran 	 54648 	 54652 	 GPE
#
#  Reuters 	 54685 	 54692 	 ORG
#
#  Hill 	 54915 	 54919 	 ORG
#
#  Italy 	 55264 	 55269 	 GPE
#
#  mafia 	 55281 	 55286 	 ORG
#
#  12/10/2018 - New York City Police Department 	 55477 	 55521 	 ORG
#
#  CNN 	 55549 	 55552 	 ORG
#
#  12/7/2018 	 55680 	 55689 	 CARDINAL
#
#  Fox News 	 55758 	 55766 	 ORG
#
#  12/6/2018 	 55894 	 55903 	 CARDINAL
#
#  U.S. 	 55913 	 55917 	 GPE
#
#  Pearl Harbor 	 55930 	 55942 	 GPE
#
#  106 	 55951 	 55954 	 CARDINAL
#
#  George H.W. Bush 	 56129 	 56145 	 PERSON
#
#  Reuters 	 56159 	 56166 	 ORG
#
#  12/4/2018 - World #1 	 56294 	 56314 	 MONEY
#
#  London 	 56372 	 56378 	 GPE
#
#  Daily Telegraph 	 56381 	 56396 	 FAC
#
#  12/3/2018 - More than 1,000 	 56524 	 56551 	 TIME
#
#  Alaska 	 56595 	 56601 	 GPE
#
#  November 2018 	 56672 	 56685 	 DATE
#
#  U.S. 	 56780 	 56784 	 GPE
#
#  Chinese 	 56809 	 56816 	 NORP
#
#  Reuters 	 56828 	 56835 	 ORG
#
#  G20 - Reuters 	 57031 	 57044 	 ORG
#
#  Ukraine 	 57185 	 57192 	 GPE
#
#  Russia 	 57220 	 57226 	 GPE
#
#  New York Post 	 57252 	 57265 	 ORG
#
#  11/27/2018 - World #1 	 57393 	 57414 	 EVENT
#
#  Czechs 	 57417 	 57423 	 NORP
#
#  EU 	 57435 	 57437 	 ORG
#
#  U.N. 	 57455 	 57459 	 ORG
#
#  Reuters 	 57477 	 57484 	 ORG
#
#  11/26/2018 	 57612 	 57622 	 CARDINAL
#
#  Mexico 	 57688 	 57694 	 GPE
#
#  CNN 	 58130 	 58133 	 ORG
#
#  Fox 	 58135 	 58138 	 ORG
#
#  CNBC 	 58140 	 58144 	 ORG
#
#  NPR 	 58146 	 58149 	 ORG
#
#  11/14/2018 - Hamas 	 58277 	 58295 	 DATE
#
#  Israel 	 58297 	 58303 	 GPE
#
#  New York Post 	 58346 	 58359 	 ORG
#
#  11/13/2018 - U.S. #1 	 58487 	 58507 	 MONEY
#
#  ILLINOIS 	 58510 	 58518 	 ORG
#
#  11/9/2018 - Veterans Day 2018 	 58706 	 58735 	 DATE
#
#  100 years 	 58752 	 58761 	 DATE
#
#  third 	 58948 	 58953 	 ORDINAL
#
#  100 years 	 58967 	 58976 	 DATE
#
#  Senate 	 58985 	 58991 	 ORG
#
#  House 	 59031 	 59036 	 ORG
#
#  AP 	 59267 	 59269 	 ORG
#
#  New York Post 	 59273 	 59286 	 ORG
#
#  11/6/2018 	 59414 	 59423 	 CARDINAL
#
#  VOA News 	 59470 	 59478 	 ORG
#
#  11/5/2018 	 59606 	 59615 	 FAC
#
#  2018 	 59650 	 59654 	 DATE
#
#  New York Post 	 59666 	 59679 	 ORG
#
#  11/2/2018 	 59807 	 59816 	 CARDINAL
#
#  Reuters 	 60118 	 60125 	 ORG
#
#  The Epoch Times 	 60130 	 60145 	 ORG
#
#  October 2018 	 60210 	 60222 	 DATE
#
#  Los Angeles Times 	 60350 	 60367 	 ORG
#
#  10/30/2018 - World #1 	 60495 	 60516 	 MONEY
#
#  Brazil 	 60551 	 60557 	 GPE
#
#  Reuters 	 60582 	 60589 	 ORG
#
#  first 	 60750 	 60755 	 ORDINAL
#
#  ICE 	 60964 	 60967 	 ORG
#
#  The Washington Post 	 61018 	 61037 	 ORG
#
#  New Hampshire 	 61191 	 61204 	 GPE
#
#  Reuters 	 61256 	 61263 	 ORG
#
#  U.S. 	 61419 	 61423 	 GPE
#
#  Russia 	 61456 	 61462 	 GPE
#
#  Norwegian 	 61620 	 61629 	 NORP
#
#  Nazis 	 61652 	 61657 	 NORP
#
#  99 	 61700 	 61702 	 CARDINAL
#
#  10/22/2018 	 61840 	 61850 	 DATE
#
#  marijuana - UPI 	 61897 	 61912 	 ORG
#
#  Simply 	 62054 	 62060 	 ORG
#
#  Thousands of pounds 	 62077 	 62096 	 QUANTITY
#
#  WDSU 	 62151 	 62155 	 ORG
#
#  Post 	 62178 	 62182 	 ORG
#
#  Courier 	 62187 	 62194 	 ORG
#
#  Honduras 	 62335 	 62343 	 GPE
#
#  Guatemala 	 62345 	 62354 	 GPE
#
#  Trump 	 62390 	 62395 	 NORP
#
#  Associated Press 	 62433 	 62449 	 ORG
#
#  Reuters 	 62454 	 62461 	 ORG
#
#  5 	 62613 	 62614 	 CARDINAL
#
#  Saudi 	 62849 	 62854 	 NORP
#
#  Reuters 	 62907 	 62914 	 ORG
#
#  10/15/2018 - UN 	 63042 	 63057 	 DATE
#
#  BBC News 	 63109 	 63117 	 ORG
#
#  France-Presse Relax News 	 63356 	 63380 	 ORG
#
#  10/11/2018 - Thousands 	 63508 	 63530 	 CARDINAL
#
#  Hurricane Michael 	 63554 	 63571 	 ORG
#
#  Florida Panhandle - WFLA NewsChannel8 	 63585 	 63622 	 ORG
#
#  NBC 	 63623 	 63626 	 ORG
#
#  Feared Repercussions of Disclosing to Public - The Wall Street Journal                                                                                                                                 	 63793 	 63991 	 WORK_OF_ART
#
#  10/9/2018 	 63991 	 64000 	 CARDINAL
#
#  Interpol 	 64014 	 64022 	 ORG
#
#  Meng Hongwei 	 64029 	 64041 	 PERSON
#
#  China 	 64062 	 64067 	 GPE
#
#  China Morning Post 	 64076 	 64094 	 ORG
#
#  Christopher Columbus 	 64234 	 64254 	 PERSON
#
#  10/4/2018 	 64399 	 64408 	 CARDINAL
#
#  UN 	 64411 	 64413 	 ORG
#
#  US 	 64435 	 64437 	 GPE
#
#  Iran 	 64446 	 64450 	 GPE
#
#  UPI 	 64463 	 64466 	 ORG
#
#  10/3/2018 	 64594 	 64603 	 CARDINAL
#
#  Canada 	 64650 	 64656 	 GPE
#
#  Mexico - UPI 	 64661 	 64673 	 ORG
#
#  10/2/2018 	 64801 	 64810 	 CARDINAL
#
#  Mexico 	 64824 	 64830 	 GPE
#
#  Acapulco 	 64846 	 64854 	 GPE
#
#  AP 	 64894 	 64896 	 ORG
#
#  NY Post 	 64900 	 64907 	 ORG
#
#  10/1/2018 	 65035 	 65044 	 CARDINAL
#
#  Arizona 	 65047 	 65054 	 GPE
#
#  Yahoo News 	 65117 	 65127 	 ORG
#
#  September 2018 	 65192 	 65206 	 DATE
#
#  Vietnam 	 65309 	 65316 	 GPE
#
#  Medal of Honor 	 65344 	 65358 	 PERSON
#
#  next month 	 65359 	 65369 	 DATE
#
#  Stars and Stripes                                                                                                                                 	 65372 	 65517 	 WORK_OF_ART
#
#  9/27/2018 	 65517 	 65526 	 DATE
#
#  the UN General Assembly 	 65545 	 65568 	 ORG
#
#  2 	 65576 	 65577 	 CARDINAL
#
#  the UN General Assembly 	 65750 	 65773 	 ORG
#
#  1 	 65781 	 65782 	 CARDINAL
#
#  New Zealand 	 65949 	 65960 	 GPE
#
#  Reuters 	 66019 	 66026 	 ORG
#
#  9/24/2018 - Delaware 	 66154 	 66174 	 DATE
#
#  Philadelphia 	 66235 	 66247 	 GPE
#
#  AP 	 66252 	 66254 	 ORG
#
#  9/21/2018 	 66382 	 66391 	 CARDINAL
#
#  Taco Bell 	 66394 	 66403 	 ORG
#
#  Spanish 	 66457 	 66464 	 NORP
#
#  Miami Herald 	 66467 	 66479 	 GPE
#
#  CBS News 	 66484 	 66492 	 ORG
#
#  9/20/2018 	 66620 	 66629 	 DATE
#
#  Georgia 	 66644 	 66651 	 GPE
#
#  Reuters 	 66725 	 66732 	 ORG
#
#  9/19/2018 - Flooding 	 66860 	 66880 	 MONEY
#
#  North Carolina 	 66890 	 66904 	 GPE
#
#  AP 	 66942 	 66944 	 ORG
#
#  13 	 66948 	 66950 	 CARDINAL
#
#  ABC News 	 66951 	 66959 	 ORG
#
#  9/18/2018 	 67087 	 67096 	 DATE
#
#  South Korea 	 67110 	 67121 	 GPE
#
#  CNN 	 67172 	 67175 	 ORG
#
#  UK Guardian 	 67177 	 67188 	 ORG
#
#  UPI 	 67193 	 67196 	 ORG
#
#  FDA 	 67359 	 67362 	 ORG
#
#  9/14/2018 	 67539 	 67548 	 PERSON
#
#  U.S. House 	 67569 	 67579 	 ORG
#
#  2017 	 67601 	 67605 	 DATE
#
#  Reuters 	 67622 	 67629 	 ORG
#
#  9/13/2018 - U.S. 	 67757 	 67773 	 DATE
#
#  Reuters 	 67829 	 67836 	 ORG
#
#  9/12/2018 - 9/11 	 67964 	 67980 	 DATE
#
#  New York Post 	 68022 	 68035 	 ORG
#
#  9/11/2018 	 68163 	 68172 	 CARDINAL
#
#  UPI 	 68252 	 68255 	 ORG
#
#  2018 	 68415 	 68419 	 DATE
#
#  9/7/2018 - Supreme Court 	 68547 	 68571 	 ORG
#
#  Ohio 	 68580 	 68584 	 GPE
#
#  Dayton Daily News 	 68619 	 68636 	 ORG
#
#  USA Today 	 68641 	 68650 	 ORG
#
#  9/6/2018 	 68778 	 68786 	 CARDINAL
#
#  Supreme Court 	 68820 	 68833 	 ORG
#
#  USA Today 	 68853 	 68862 	 ORG
#
#  Kentucky 	 69001 	 69009 	 GPE
#
#  Reuters 	 69062 	 69069 	 ORG
#
#  UPI 	 69074 	 69077 	 ORG
#
#  June 2018 	 69142 	 69151 	 DATE
#
#  U.S. Supreme Court 	 69226 	 69244 	 ORG
#
#  Minnesota 	 69258 	 69267 	 GPE
#
#  UPI 	 69292 	 69295 	 ORG
#
#  WSJ 	 69301 	 69304 	 ORG
#
#  Boston Herald 	 69309 	 69322 	 ORG
#
#  6/8/2018 	 69450 	 69458 	 CARDINAL
#
#  Chinese 	 69487 	 69494 	 NORP
#
#  The Verge                                                                 May 2018 	 69507 	 69589 	 WORK_OF_ART
#
#  Memorial Day 2018 - USMemorialDay.org                                                                                                                                 	 69683 	 69848 	 EVENT
#
#  5/24/2018 	 69848 	 69857 	 DATE
#
#  Hawaii 	 69860 	 69866 	 GPE
#
#  New York Post 	 69924 	 69937 	 ORG
#
#  5/23/2018 	 70065 	 70074 	 DATE
#
#  Amazon 	 70083 	 70089 	 ORG
#
#  AP 	 70139 	 70141 	 ORG
#
#  ABC News 	 70145 	 70153 	 ORG
#
#  5/22/2018 	 70281 	 70290 	 DATE
#
#  GERMANY 	 70304 	 70311 	 ORG
#
#  NATO - UPI 	 70343 	 70353 	 ORG
#
#  NBC News 	 70358 	 70366 	 ORG
#
#  5/21/2018 	 70494 	 70503 	 DATE
#
#  Durango Herald 	 70582 	 70596 	 PERSON
#
#  5/18/2018 	 70724 	 70733 	 DATE
#
#  2019 	 70762 	 70766 	 DATE
#
#  5/17/2018 	 70901 	 70910 	 QUANTITY
#
#  White House 	 70913 	 70924 	 ORG
#
#  Pyongyang 	 70958 	 70967 	 GPE
#
#  New York Post 	 70993 	 71006 	 ORG
#
#  Reuters 	 71011 	 71018 	 ORG
#
#  5/16/2018 	 71146 	 71155 	 DATE
#
#  DHS 	 71158 	 71161 	 ORG
#
#  Congress 	 71167 	 71175 	 ORG
#
#  Reuters 	 71219 	 71226 	 ORG
#
#  5/15/2018 	 71354 	 71363 	 DATE
#
#  1 	 71378 	 71379 	 MONEY
#
#  ISRAEL 	 71382 	 71388 	 GPE
#
#  U.S. 	 71390 	 71394 	 GPE
#
#  Jerusalem 	 71412 	 71421 	 GPE
#
#  Fox News 	 71459 	 71467 	 ORG
#
#  5/14/2018 	 71595 	 71604 	 DATE
#
#  US Navy 	 71607 	 71614 	 ORG
#
#  Atlantic 2nd Fleet - Agence France-Presse 	 71631 	 71672 	 ORG
#
#  5/11/2018 	 71800 	 71809 	 DATE
#
#  1 	 72047 	 72048 	 MONEY
#
#  U.S. 	 72063 	 72067 	 GPE
#
#  DJIBOUTI 	 72080 	 72088 	 GPE
#
#  UPI 	 72112 	 72115 	 ORG
#  5/7/2018 - Iowa 	 72243 	 72258 	 DATE
#
#  Catholic News Agency 	 72306 	 72326 	 ORG
#
#  5/4/2018 	 72454 	 72462 	 CARDINAL
#
#  Haley 	 72465 	 72470 	 GPE
#
#  America 	 72521 	 72528 	 GPE
#
#  UN 	 72539 	 72541 	 ORG
#
#  n’t - Fox News 	 72561 	 72575 	 ORG
#
#  5/3/2018 - Calif. 	 72703 	 72720 	 DATE
#
#  7-Eleven 	 72721 	 72729 	 ORG
#
#  5/2/2018 	 72930 	 72938 	 DATE
#
#  Reuters 	 72985 	 72992 	 ORG
#
#  5/1/2018 - World #1 	 73120 	 73139 	 MONEY
#
#  N. Korea 	 73142 	 73150 	 GPE
#
#  May 	 73187 	 73190 	 DATE
#
#  US 	 73199 	 73201 	 GPE
#
#  Agence France-Presse 	 73212 	 73232 	 ORG
#
#  April 2018 	 73297 	 73307 	 DATE
#
#  4/30/2018 - U.S. 	 73370 	 73386 	 DATE
#
#  Saudi Arabia 	 73388 	 73400 	 GPE
#
#  Israel 	 73405 	 73411 	 GPE
#
#  Iran 	 73414 	 73418 	 GPE
#
#  NY Post 	 73453 	 73460 	 ORG
#
#  4/27/2018 	 73588 	 73597 	 DATE
#
#  Rock’ - Philly.com 	 73613 	 73631 	 ORG
#
#  USA Today 	 73636 	 73645 	 ORG
#
#  nearly $400M 	 73821 	 73833 	 MONEY
#
#  Coast Guard - New York Post 	 73844 	 73871 	 ORG
#
#  4/25/2018 	 73999 	 74008 	 DATE
#
#  50 years 	 74020 	 74028 	 DATE
#
#  $1.2M 	 74042 	 74047 	 MONEY
#
#  UPI 	 74081 	 74084 	 ORG
#
#  NBC News 	 74086 	 74094 	 ORG
#
#  the Brownsville Herald 	 74099 	 74121 	 ORG
#
#  4/24/2018 	 74249 	 74258 	 DATE
#
#  1 	 74273 	 74274 	 MONEY
#
#  Canada 	 74277 	 74283 	 GPE
#
#  Cuba 	 74315 	 74319 	 GPE
#
#  UK 	 74344 	 74346 	 GPE
#
#  Sky News 	 74349 	 74357 	 ORG
#
#  4/23/2018 - Dozens 	 74485 	 74503 	 DATE
#
#  MS-13 	 74507 	 74512 	 PRODUCT
#
#  4/20/2018 	 74708 	 74717 	 DATE
#
#  2 	 74739 	 74740 	 CARDINAL
#
#  Fentanyl 	 74762 	 74770 	 GPE
#
#  The Daily Caller 	 74800 	 74816 	 WORK_OF_ART
#
#  Kim Jong Un - 	 74987 	 75000 	 PERSON
#
#  New York Post 	 75001 	 75014 	 ORG
#
#  4/18/2018 	 75142 	 75151 	 DATE
#
#  The Wall Street Journal 	 75204 	 75227 	 ORG
#
#  4/17/2018 - Tuesday 	 75355 	 75374 	 DATE
#
#  Israel - Compiled 	 75388 	 75405 	 ORG
#
#  CNN 	 75411 	 75414 	 ORG
#
#  UPI 	 75416 	 75419 	 ORG
#
#  NY Post 	 75424 	 75431 	 ORG
#
#  4/16/2018 	 75559 	 75568 	 DATE
#
#  Tiny Baseball Bats - Erie News Now 	 75606 	 75640 	 ORG
#
#  Israel 	 75780 	 75786 	 GPE
#
#  Holocaust 	 75819 	 75828 	 GPE
#
#  4/12/2018 	 75999 	 76008 	 CARDINAL
#
#  U.S. 	 76042 	 76046 	 GPE
#
#  Syria - United Press International - UPI 	 76065 	 76105 	 ORG
#
#  4/11/2018 	 76233 	 76242 	 DATE
#
#  China 	 76245 	 76250 	 GPE
#
#  Trump - AP 	 76293 	 76303 	 ORG
#
#  CBSNews 	 76307 	 76314 	 CARDINAL
#
#  London 	 76475 	 76481 	 GPE
#
#  Daily Telegraph 	 76513 	 76528 	 ORG
#
#  FoxNews 	 76530 	 76537 	 ORG
#
#  Daily Wire and Daily Caller 	 76543 	 76570 	 ORG
#
#  4/9/2018 - Facebook 	 76698 	 76717 	 TIME
#
#  Zuckerberg 	 76726 	 76736 	 PERSON
#
#  Tech Crunch 	 76775 	 76786 	 PERSON
#
#  4/6/2018 	 76914 	 76922 	 CARDINAL
#
#  Justice Department 	 76925 	 76943 	 ORG
#
#  over 100 	 76951 	 76959 	 CARDINAL
#
#  Reuters 	 77004 	 77011 	 ORG
#
#  4/5/2018 - Mobile 	 77139 	 77156 	 MONEY
#
#  D.C. - United Press International 	 77188 	 77221 	 ORG
#
#  UPI 	 77223 	 77226 	 ORG
#
#  4/4/2018 	 77355 	 77363 	 CARDINAL
#
#  50 miles 	 77377 	 77385 	 QUANTITY
#
#  Memphis 	 77389 	 77396 	 GPE
#
#  Martin Luther King Jr. - CNN 	 77406 	 77434 	 PERSON
#
#  4/3/2018 - Tuesday 	 77562 	 77580 	 DATE
#
#  #1 	 77589 	 77591 	 CARDINAL
#
#  South Korea 	 77593 	 77604 	 GPE
#
#  U.S. 	 77606 	 77610 	 GPE
#
#  UPI 	 77642 	 77645 	 ORG
#
#  4/2/2018 	 77773 	 77781 	 CARDINAL
#
#  2nd 	 77834 	 77837 	 ORDINAL
#
#  Today 	 77854 	 77859 	 DATE
#
#  Florida 	 77862 	 77869 	 GPE
#
#  March 2018 	 77940 	 77950 	 DATE
#
#  3/30/2018 - A day 	 78013 	 78030 	 DATE
#
#  Vietnam War Vets - UPI 	 78040 	 78062 	 EVENT
#
#  3/29/2018 	 78190 	 78199 	 DATE
#
#  West Virginia 	 78224 	 78237 	 GPE
#
#  Hill 	 78277 	 78281 	 LOC
#
#  UPI 	 78478 	 78481 	 ORG
#
#  $1.3 trillion 	 78633 	 78646 	 MONEY
#
#  Huffington Post 	 78714 	 78729 	 ORG
#
#  UPI 	 78734 	 78737 	 ORG
#
#  3/23/2018 	 78865 	 78874 	 CARDINAL
#
#  China 	 78904 	 78909 	 GPE
#
#  Reuters 	 78959 	 78966 	 ORG
#
#  Hill 	 78972 	 78976 	 GPE
#
#  Washington Examiner 	 78981 	 79000 	 ORG
#
#  3/22/2018 - California 	 79128 	 79150 	 DATE
#
#  3/21/2018 	 79333 	 79342 	 CARDINAL
#
#  CBS 	 79402 	 79405 	 ORG
#
#  National Review and Fox59 	 79407 	 79432 	 ORG
#
#  3/20/2018 - Tuesday 	 79560 	 79579 	 DATE
#
#  BELGIUM - Associated Press 	 79593 	 79619 	 ORG
#
#  Chicago 	 79816 	 79823 	 GPE
#
#  The Wall Street Journal 	 79826 	 79849 	 ORG
#
#  3/16/2018 	 79977 	 79986 	 CARDINAL
#
#  UPI 	 80061 	 80064 	 ORG
#
#  TX 	 80231 	 80233 	 ORG
#
#  UPI 	 80286 	 80289 	 ORG
#
#  3/14/2018 	 80417 	 80426 	 CARDINAL
#
#  Arkansas 	 80429 	 80437 	 GPE
#
#  Arkansas 	 80496 	 80504 	 GPE
#
#  Democrat 	 80505 	 80513 	 NORP
#
#  Breitbart 	 80523 	 80532 	 GPE
#
#  USA Today 	 80534 	 80543 	 ORG
#
#  Fox Insider 	 80548 	 80559 	 ORG
#
#  3/13/2018 - Tuesday 	 80687 	 80706 	 DATE
#
#  3/12/2018 	 80870 	 80879 	 CARDINAL
#
#  Kim Jong Un - UPI 	 80908 	 80925 	 PERSON
#
#  Uber 	 81077 	 81081 	 PERSON
#
#  Arizona 	 81110 	 81117 	 GPE
#
#  California 	 81281 	 81291 	 GPE
#
#  Hill 	 81323 	 81327 	 LOC
#
#  3/6/2018 - Tuesday 	 81676 	 81694 	 DATE
#
#  5B 	 81880 	 81882 	 MONEY
#
#  UK Daily Mail 	 81931 	 81944 	 ORG
#
#  3/2/2018 - Miami International Airport 	 82072 	 82110 	 QUANTITY
#
#  3/1/2018 	 82290 	 82298 	 CARDINAL
#
#  Supreme Court 	 82321 	 82334 	 ORG
#
#  NBC News 	 82348 	 82356 	 ORG
#
#  February 2018 	 82421 	 82434 	 DATE
#
#  CNBC 	 82588 	 82592 	 ORG
#
#  2/27/2018 - Tuesday 	 82720 	 82739 	 DATE
#
#  PAKISTAN 	 82753 	 82761 	 ORG
#
#  2/26/2018 	 82899 	 82908 	 DATE
#
#  U.S. 	 82922 	 82926 	 GPE
#
#  North Korea 	 82959 	 82970 	 GPE
#
#  Reuters 	 83001 	 83008 	 ORG
#
#  2/23/2018 	 83136 	 83145 	 DATE
#
#  UPI 	 83194 	 83197 	 ORG
#
#  2/22/2018 	 83325 	 83334 	 DATE
#
#  Billy Graham 	 83337 	 83349 	 PERSON
#
#  New Mexico 	 83551 	 83561 	 GPE
#
#  USA Today 	 83628 	 83637 	 ORG
#
#  2/20/2018 - Tuesday 	 83765 	 83784 	 DATE
#
#  France-Presse 	 83817 	 83830 	 ORG
#
#  2/19/2018 	 83958 	 83967 	 CARDINAL
#
#  2/16/2018 	 84137 	 84146 	 DATE
#
#  George Washington 	 84149 	 84166 	 PERSON
#
#  2/15/2018 	 84317 	 84326 	 DATE
#
#  U.S. 	 84329 	 84333 	 GPE
#
#  April 20, day 	 84373 	 84386 	 DATE
#
#  Portland Press Herald 	 84403 	 84424 	 ORG
#
#  Associated Press 	 84615 	 84631 	 ORG
#
#  2/13/2018 - Tuesday 	 84759 	 84778 	 DATE
#
#  KENYA - UK Daily Telegraph 	 84792 	 84818 	 ORG
#
#  2/12/2018 - Meet 	 84946 	 84962 	 MONEY
#
#  first 	 84967 	 84972 	 ORDINAL
#
#  Lucas 	 85017 	 85022 	 GPE
#
#  The Herald-Sun                                                                                                                                 	 85039 	 85181 	 ORG
#
#  U.S. 	 85192 	 85196 	 GPE
#
#  100 	 85213 	 85216 	 CARDINAL
#
#  Syrian 	 85217 	 85223 	 NORP
#
#  USA Today 	 85279 	 85288 	 ORG
#
#  AP 	 85293 	 85295 	 ORG
#
#  Chicago Sun Times 	 85299 	 85316 	 ORG
#
#  2/8/2018 	 85444 	 85452 	 CARDINAL
#
#  Saudi 	 85455 	 85460 	 NORP
#
#  Oklahoma 	 85468 	 85476 	 GPE
#
#  al Qaeda 	 85502 	 85510 	 ORG
#
#  Reuters 	 85522 	 85529 	 ORG
#
#  2/7/2018 	 85657 	 85665 	 CARDINAL
#
#  2/6/2018 - Tuesday 	 85856 	 85874 	 DATE
#
#  Deutsche Welle 	 85910 	 85924 	 ORG
#
#  2/5/2018 	 86052 	 86060 	 CARDINAL
#
#  Associated Press 	 86123 	 86139 	 ORG
#
#  2/2/2018 	 86267 	 86275 	 CARDINAL
#
#  Super Bowl 	 86278 	 86288 	 EVENT
#
#  Reuters 	 86326 	 86333 	 ORG
#
#  2/1/2018 	 86473 	 86481 	 CARDINAL
#
#  U.S. 	 86492 	 86496 	 GPE
#
#  January 2018 	 86633 	 86645 	 DATE
#
#  Tech Crunch 	 86769 	 86780 	 PERSON
#
#  1/30/2018 - Tuesday 	 86908 	 86927 	 DATE
#
#  1 	 86937 	 86938 	 MONEY
#
#  POLAND 	 86941 	 86947 	 ORG
#
#  1/29/2018 	 87092 	 87101 	 DATE
#
#  first 	 87112 	 87117 	 ORDINAL
#
#  the Union Address - ABC News 	 87127 	 87155 	 ORG
#
#  1/26/2018 	 87283 	 87292 	 DATE
#
#  UK 	 87356 	 87358 	 GPE
#
#  Swindon Advertiser 	 87372 	 87390 	 ORG
#
#  1/24/2018 - Delta 	 87751 	 87768 	 DATE
#
#  CBS News / 	 87832 	 87842 	 ORG
#
#  1/23/2018 - Tuesday 	 87973 	 87992 	 DATE
#
#  The Walll Street Journal 	 88017 	 88041 	 ORG
#
#  1/22/2018 	 88169 	 88178 	 DATE
#
#  Delaware 	 88181 	 88189 	 GPE
#
#  Reuters 	 88246 	 88253 	 ORG
#
#  1/17/2018 - U.S. 	 88381 	 88397 	 DATE
#
#  AT&T 	 88413 	 88417 	 ORG
#
#  Huawei - Reuters 	 88446 	 88462 	 ORG
#
#  1/16/2018 - Tuesday 	 88590 	 88609 	 DATE
#
#  CHILE - Christianity 	 88623 	 88643 	 ORG
#
#  Today 	 88644 	 88649 	 DATE
#
#  1/12/2018 	 88777 	 88786 	 DATE
#
#  Martin Luther King Jr. Day 	 88789 	 88815 	 PERSON
#
#  1/10/2018 - 2018 	 88948 	 88964 	 DATE
#
#  State 	 88978 	 88983 	 ORG
#
#  1/9/2018 - Tuesday 	 89121 	 89139 	 DATE
#
#  Status - Washington Examiner 	 89199 	 89227 	 ORG
#
#  1/8/2018 	 89355 	 89363 	 CARDINAL
#
#  billions 	 89390 	 89398 	 CARDINAL
#
#  December 2017 	 89486 	 89499 	 DATE
#
#  Jan. 8 	 89583 	 89589 	 DATE
#
#  U.S. Military’s 	 89592 	 89607 	 ORG
#
#  12/20/2017 - Merry Christmas 	 89763 	 89791 	 DATE
#
#  January 8                                                                                                                                12/19/2017 - Tuesday 	 89802 	 89959 	 DATE
#
#  JAPAN 	 89973 	 89978 	 GPE
#
#  Millions 	 89980 	 89988 	 CARDINAL
#
#  Tokyo 	 89992 	 89997 	 GPE
#
#  North Korean 	 90014 	 90026 	 NORP
#
#  London 	 90053 	 90059 	 GPE
#
#  Daily Telegraph 	 90062 	 90077 	 ORG
#
#  Planned Bioterror Test - 	 90248 	 90272 	 ORG
#
#  12/14/2017 	 90411 	 90421 	 DATE
#
#  Afghanistan 	 90451 	 90462 	 GPE
#
#  12/13/2017 - U.S. 	 90599 	 90616 	 DATE
#
#  12/12/2017 - Tuesday 	 90823 	 90843 	 DATE
#
#  RUSSIA 	 90857 	 90863 	 ORG
#
#  Olympic 	 90866 	 90873 	 GPE
#
#  Winter Olympics 	 90891 	 90906 	 EVENT
#
#  New York Post 	 90929 	 90942 	 ORG
#
#  12/8/2017 	 91070 	 91079 	 CARDINAL
#
#  76th 	 91111 	 91115 	 ORDINAL
#
#  Pearl Harbor 	 91131 	 91143 	 GPE
#
#  Hawaii News 	 91153 	 91164 	 ORG
#
#  U.S. 	 91335 	 91339 	 GPE
#
#  Jerusalem 	 91351 	 91360 	 GPE
#
#  12/6/2017 	 91505 	 91514 	 CARDINAL
#
#  Wisconsin 	 91517 	 91526 	 GPE
#
#  Star Tribune 	 91582 	 91594 	 ORG
#
#  12/5/2017 - Tuesday 	 91722 	 91741 	 DATE
#
#  U.S. 	 91767 	 91771 	 GPE
#
#  Reuters 	 91802 	 91809 	 ORG
#
#  12/4/2017 - Supreme Court 	 91937 	 91962 	 ORG
#
#  AP 	 92017 	 92019 	 ORG
#
#  Chicago Sun-Times 	 92023 	 92040 	 ORG
#
#  12/1/2017 	 92168 	 92177 	 CARDINAL
#
#  US 	 92180 	 92182 	 GPE
#
#  North Korean 	 92184 	 92196 	 NORP
#
#  CBS News 	 92247 	 92255 	 ORG
#
#  November 2017 	 92320 	 92333 	 DATE
#
#  Los Angeles Times 	 92502 	 92519 	 ORG
#
#  11/29/2017 - Justice Department 	 92647 	 92678 	 PERCENT
#
#  Harvard 	 92696 	 92703 	 ORG
#
#  Asian-American 	 92709 	 92723 	 NORP
#
#  Mass Live and Daily Caller 	 92744 	 92770 	 ORG
#
#  11/28/2017 - Tuesday 	 92898 	 92918 	 DATE
#
#  40 year 	 92972 	 92979 	 DATE
#
#  Reuters 	 92987 	 92994 	 ORG
#
#  11/27/2017 - Chicago 	 93122 	 93142 	 DATE
#
#  11/20/2017 - Thanksgiving 2017 	 93350 	 93380 	 DATE
#
#  MS-13 	 93533 	 93538 	 PRODUCT
#
#  Operation Raging Bull’ 	 93565 	 93587 	 WORK_OF_ART
#
#  NBC News 	 93590 	 93598 	 ORG
#
#  Washington Free Beacon 	 93603 	 93625 	 FAC
#
#  London 	 94042 	 94048 	 GPE
#
#  Daily Telegraph 	 94051 	 94066 	 ORG
#
#  11/14/2017 - Tuesday 	 94194 	 94214 	 DATE
#
#  Asia 	 94228 	 94232 	 LOC
#
#  11/13/2017 	 94393 	 94403 	 CARDINAL
#
#  Daily Telegraph 	 94466 	 94481 	 ORG
#
#  Sunday 	 94675 	 94681 	 DATE
#
#  EPA 	 94821 	 94824 	 ORG
#
#  11/8/2017 - Pa. 	 95017 	 95032 	 DATE
#
#  Inquirer 	 95100 	 95108 	 ORG
#
#  11/7/2017 - Tuesday 	 95247 	 95266 	 DATE
#
#  World News 	 95269 	 95279 	 ORG
#
#  1 	 95281 	 95282 	 MONEY
#
#  Lebanon - BBC News 	 95285 	 95303 	 ORG
#
#  Reuters 	 95308 	 95315 	 ORG
#
#  11/6/2017 - US 	 95443 	 95457 	 MONEY
#
#  Bowe Bergdahl 	 95467 	 95480 	 PERSON
#
#  The Hill                                                                  	 95502 	 95575 	 WORK_OF_ART
#
#  October 2017 	 95575 	 95587 	 DATE
#
#  $4 trillion 	 95676 	 95687 	 MONEY
#
#  Trump 	 95711 	 95716 	 PRODUCT
#
#  New York Post 	 95728 	 95741 	 ORG
#
#  10/26/2017 	 95869 	 95879 	 CARDINAL
#
#  11 	 95922 	 95924 	 CARDINAL
#
#  Reuters 	 95947 	 95954 	 ORG
#
#  Green Beret 	 96095 	 96106 	 GPE
#
#  Medal of Honor - CBS News 	 96121 	 96146 	 PERSON
#
#  10/24/2017 - Tuesday 	 96274 	 96294 	 DATE
#
#  World News 	 96297 	 96307 	 ORG
#
#  1 	 96309 	 96310 	 MONEY
#
#  Syria - NY Post 	 96313 	 96328 	 ORG
#
#  10/23/2017 	 96456 	 96466 	 DATE
#
#  Congress 	 96469 	 96477 	 ORG
#
#  The Daily Caller 	 96557 	 96573 	 WORK_OF_ART
#
#  K-9 Medal of Courage - Washington Examiner 	 96741 	 96783 	 WORK_OF_ART
#
#  American Humane 	 96788 	 96803 	 ORG
#
#  10/19/2017 - U.S. 	 96931 	 96948 	 DATE
#
#  Chinese 	 96963 	 96970 	 NORP
#
#  Reuters 	 97013 	 97020 	 ORG
#
#  Los Angeles 	 97220 	 97231 	 GPE
#
#  10/17/2017 	 97359 	 97369 	 CARDINAL
#
#  Chelsea 	 97372 	 97379 	 PERSON
#
#  Ahmad Rahimi 	 97387 	 97399 	 PERSON
#
#  CBS News / 	 97430 	 97440 	 ORG
#
#  WREG News Channel 	 97647 	 97664 	 ORG
#
#  San Antonio Express-News 	 97671 	 97695 	 ORG
#
#  10/13/2017 - Shake Shack 	 97823 	 97847 	 EVENT
#
#  NYC 	 97860 	 97863 	 LOC
#
#  Fox News 	 97915 	 97923 	 ORG
#
#  NY Post 	 97928 	 97935 	 ORG
#
#  10/12/2017 	 98063 	 98073 	 DATE
#
#  U.S. 	 98076 	 98080 	 GPE
#
#  $12 Million 	 98088 	 98099 	 MONEY
#
#  Two 	 98113 	 98116 	 CARDINAL
#
#  Reuters 	 98372 	 98379 	 ORG
#
#  California 	 98529 	 98539 	 GPE
#
#  Los Angeles Times 	 98584 	 98601 	 ORG
#
#  10/9/2017 - Columbus 	 98729 	 98749 	 MONEY
#
#  10/6/2017 	 98894 	 98903 	 CARDINAL
#
#  Green Berets 	 98908 	 98920 	 ORG
#
#  10/5/2017 	 99080 	 99089 	 CARDINAL
#
#  U.S. 	 99092 	 99096 	 GPE
#
#  Nobel 	 99112 	 99117 	 WORK_OF_ART
#
#  Einstein 	 99130 	 99138 	 PERSON
#
#  Reuters 	 99163 	 99170 	 ORG
#
#  10/4/2017 	 99298 	 99307 	 CARDINAL
#
#  U.S. 	 99310 	 99314 	 GPE
#
#  Nobel - Reuters 	 99343 	 99358 	 WORK_OF_ART
#
#  10/3/2017 	 99486 	 99495 	 DATE
#
#  Reuters 	 99556 	 99563 	 ORG
#
#  10/2/2017 	 99691 	 99700 	 CARDINAL
#
#  North Korea 	 99744 	 99755 	 GPE
#
#  New York Post 	 99758 	 99771 	 ORG
#
#  September 2017 	 99836 	 99850 	 DATE
#
#  Puerto Rico 	 99973 	 99984 	 GPE
#
#  Reuters 	 100010 	 100017 	 ORG
#
#  The Wall Street Journal 	 100022 	 100045 	 ORG
#
#  9/28/2017 	 100173 	 100182 	 CARDINAL
#
#  The Daily Caller 	 100240 	 100256 	 WORK_OF_ART
#
#  9/27/2017 - 4 	 100384 	 100397 	 CARDINAL
#
#  NCAA 	 100398 	 100402 	 ORG
#
#  9/26/2017 	 100615 	 100624 	 DATE
#
#  North Korea 	 100653 	 100664 	 GPE
#
#  Venezuela 	 100666 	 100675 	 GPE
#
#  Chad 	 100680 	 100684 	 GPE
#
#  The New York Post 	 100687 	 100704 	 ORG
#
#  9/25/2017 	 100832 	 100841 	 DATE
#
#  China 	 100862 	 100867 	 GPE
#
#  U.S. 	 100884 	 100888 	 GPE
#
#  ABC News 	 100891 	 100899 	 ORG
#
#  9/22/2017 - Power 	 101027 	 101044 	 FAC
#
#  Puerto Rico 	 101063 	 101074 	 GPE
#
#  Maria 	 101081 	 101086 	 GPE
#
#  Reuters 	 101106 	 101113 	 ORG
#
#  9/21/2017 	 101241 	 101250 	 DATE
#
#  Trump 	 101272 	 101277 	 PERSON
#
#  UN 	 101289 	 101291 	 ORG
#
#  2 	 101298 	 101299 	 CARDINAL
#
#  Trump 	 101459 	 101464 	 PERSON
#
#  UN 	 101476 	 101478 	 ORG
#
#  1 	 101485 	 101486 	 CARDINAL
#
#  U.S. 	 101631 	 101635 	 GPE
#
#  Cuba 	 101677 	 101681 	 GPE
#
#  CBS News 	 101709 	 101717 	 ORG
#
#  9/18/2017 - Focus of Trump’s 	 101845 	 101873 	 DATE
#
#  1st 	 101874 	 101877 	 DATE
#
#  U.N. 	 101888 	 101892 	 ORG
#
#  NPR 	 101921 	 101924 	 ORG
#
#  Reuters 	 101929 	 101936 	 ORG
#
#  9/15/2017 	 102064 	 102073 	 DATE
#  Houston Council 	 102076 	 102091 	 ORG
#
#  Red Cross - Houston Press 	 102134 	 102159 	 ORG
#
#  The Wall Street Journal 	 102351 	 102374 	 ORG
#
#  Chicago Tribune 	 102581 	 102596 	 ORG
#
#  9/12/2017 - Irma 	 102724 	 102740 	 ORG
#
#  about 7.3 million 	 102761 	 102778 	 CARDINAL
#
#  Reuters 	 102781 	 102788 	 ORG
#
#  9/11/2017 - 	 102916 	 102927 	 DATE
#
#  9/8/2017 - Trump 	 103107 	 103123 	 PRODUCT
#
#  Democrats 	 103135 	 103144 	 NORP
#
#  Reuters 	 103161 	 103168 	 ORG
#
#  9/7/2017 	 103296 	 103304 	 CARDINAL
#
#  - Appeals 	 103305 	 103314 	 ORG
#
#  Texas 	 103327 	 103332 	 GPE
#
#  The Hill 	 103360 	 103368 	 LOC
#
#  North Korea 	 103520 	 103531 	 GPE
#
#  US 	 103579 	 103581 	 GPE
#
#  The Hill 	 103592 	 103600 	 LOC
#
#  May 2017 	 103665 	 103673 	 DATE
#
#  5/26/2017 	 103736 	 103745 	 DATE
#
#  Memorial Day 2017 - USMemorialDay.org 	 103767 	 103804 	 EVENT
#
#  5/25/2017 - Thousands 	 103932 	 103953 	 CARDINAL
#
#  Philippine 	 103959 	 103969 	 NORP
#
#  Islamic State - Compiled 	 103992 	 104016 	 ORG
#
#  Reuters 	 104022 	 104029 	 ORG
#
#  The Straits Times 	 104034 	 104051 	 ORG
#
#  Israel 	 104209 	 104215 	 GPE
#
#  Jerusalem 	 104219 	 104228 	 GPE
#
#  5/23/2017 	 104373 	 104382 	 DATE
#
#  Turkish 	 104385 	 104392 	 NORP
#
#  D.C. - The Daily Caller 	 104438 	 104461 	 ORG
#
#  5/22/2017 - Trump 	 104589 	 104606 	 DATE
#
#  Muslim 	 104628 	 104634 	 NORP
#
#  5/19/2017 	 104794 	 104803 	 DATE
#
#  Cincinnati 	 104889 	 104899 	 GPE
#
#  5/18/2017 	 105027 	 105036 	 DATE
#
#  Tennessee 	 105039 	 105048 	 GPE
#
#  5/17/2017 - 	 105232 	 105243 	 DATE
#
#  CNN 	 105301 	 105304 	 ORG
#
#  CBSNews 	 105309 	 105316 	 PRODUCT
#
#  5/16/2017 	 105444 	 105453 	 DATE
#
#  China 	 105456 	 105461 	 GPE
#
#  NY Daily News 	 105521 	 105534 	 ORG
#
#  5/15/2017 	 105662 	 105671 	 DATE
#
#  US 	 105674 	 105676 	 GPE
#
#  Europe 	 105717 	 105723 	 LOC
#
#  AP 	 105735 	 105737 	 PRODUCT
#
#  5/12/2017 - Texas 	 105865 	 105882 	 DATE
#
#  Fox News/AP 	 105930 	 105941 	 ORG
#
#  5/11/2017 	 106069 	 106078 	 DATE
#
#  two-year 	 106123 	 106131 	 DATE
#
#  UK 	 106160 	 106162 	 GPE
#
#  Nazi 	 106336 	 106340 	 NORP
#
#  Germany 	 106341 	 106348 	 GPE
#
#  72 years ago 	 106361 	 106373 	 DATE
#
#  VE Day - Business Insider 	 106387 	 106412 	 ORG
#
#  Hamas 	 106569 	 106574 	 ORG
#
#  Reuters 	 106595 	 106602 	 ORG
#
#  5/8/2017 	 106730 	 106738 	 CARDINAL
#
#  VA 	 106741 	 106743 	 GPE
#
#  over 1,100 	 106774 	 106784 	 CARDINAL
#
#  CBS News/AP 	 106798 	 106809 	 ORG
#
#  5/5/2017 - Battle 	 106937 	 106954 	 DATE
#
#  75th 	 106968 	 106972 	 ORDINAL
#
#  New York Post 	 106987 	 107000 	 ORG
#
#  5/4/2017 	 107128 	 107136 	 CARDINAL
#
#  Saigon 	 107181 	 107187 	 GPE
#
#  Run Trump 	 107347 	 107356 	 PERSON
#
#  The Daily Caller 	 107442 	 107458 	 WORK_OF_ART
#
#  5/2/2017 	 107586 	 107594 	 CARDINAL
#
#  Australian 	 107637 	 107647 	 NORP
#
#  5/1/2017 	 107775 	 107783 	 CARDINAL
#
#  U.S. 	 107786 	 107790 	 GPE
#
#  Reuters 	 107850 	 107857 	 ORG
#
#  April 2017 	 107922 	 107932 	 DATE
#
#  4/28/2017 	 107995 	 108004 	 DATE
#
#  GOP 	 108067 	 108070 	 ORG
#
#  The Washington Post 	 108082 	 108101 	 ORG
#
#  4/27/2017 - U.S. 	 108229 	 108245 	 DATE
#
#  CBS News 	 108277 	 108285 	 ORG
#
#  4/26/2017 	 108413 	 108422 	 DATE
#
#  U.S. Senate 	 108432 	 108443 	 ORG
#
#  White House 	 108453 	 108464 	 ORG
#
#  North Korea 	 108469 	 108480 	 GPE
#
#  Reuters 	 108506 	 108513 	 ORG
#
#  Reuters Trust 	 108515 	 108528 	 ORG
#
#  UK Guardian 	 108533 	 108544 	 ORG
#
#  4/25/2017 	 108672 	 108681 	 DATE
#
#  Reuters 	 108728 	 108735 	 ORG
#
#  4/24/2017 - 	 108863 	 108874 	 TIME
#
#  2017 	 108887 	 108891 	 DATE
#
#  Nazi 	 108925 	 108929 	 NORP
#
#  Metro News 	 108945 	 108955 	 ORG
#
#  4/21/2017 	 109083 	 109092 	 DATE
#
#  US 	 109105 	 109107 	 GPE
#
#  Venezuela 	 109141 	 109150 	 GPE
#
#  ABC News 	 109153 	 109161 	 ORG
#
#  4/20/2017 	 109289 	 109298 	 DATE
#
#  Doolittle Raid’ 	 109515 	 109530 	 ORG
#
#  75th 	 109550 	 109554 	 ORDINAL
#
#  4/18/2017 - Pence 	 109700 	 109717 	 MONEY
#
#  North Korea 	 109724 	 109735 	 GPE
#
#  U.S. 	 109739 	 109743 	 GPE
#
#  Syria 	 109761 	 109766 	 GPE
#
#  Afghan 	 109768 	 109774 	 NORP
#
#  Reuters 	 109785 	 109792 	 ORG
#
#  4/17/2017 	 109920 	 109929 	 DATE
#
#  Reuters 	 109978 	 109985 	 ORG
#
#  4/14/2017 	 110113 	 110122 	 DATE
#
#  US 	 110125 	 110127 	 GPE
#
#  Afghanistan 	 110174 	 110185 	 GPE
#
#  New York Post 	 110188 	 110201 	 ORG
#
#  4/13/2017 	 110329 	 110338 	 DATE
#
#  U.S. 	 110365 	 110369 	 GPE
#
#  Los Angeles Times 	 110395 	 110412 	 ORG
#
#  4/12/2017 	 110540 	 110549 	 DATE
#
#  Trump 	 110564 	 110569 	 PERSON
#
#  Window of Opportunity 	 110572 	 110593 	 WORK_OF_ART
#
#  Russia 	 110614 	 110620 	 GPE
#
#  Syria - London's 	 110640 	 110656 	 ORG
#
#  Daily Telegraph 	 110657 	 110672 	 ORG
#
#  4/11/2017 - Gorsuch 	 110800 	 110819 	 DATE
#
#  Supreme Court 	 110842 	 110855 	 ORG
#
#  New York Post 	 110864 	 110877 	 ORG
#
#  4/10/2017 - 	 111005 	 111016 	 TIME
#
#  Syria 	 111028 	 111033 	 GPE
#
#  North Korea 	 111072 	 111083 	 GPE
#
#  4/7/2017 	 111221 	 111229 	 CARDINAL
#
#  Syria 	 111262 	 111267 	 GPE
#
#  Reuters 	 111289 	 111296 	 ORG
#
#  4/6/2017 	 111424 	 111432 	 DATE
#
#  4/5/2017 - ICE 	 111609 	 111623 	 DATE
#
#  Reuters 	 111661 	 111668 	 ORG
#
#  4/4/2017 	 111796 	 111804 	 CARDINAL
#
#  Egypt 	 111850 	 111855 	 GPE
#
#  Reuters 	 111859 	 111866 	 ORG
#
#  4/3/2017 - 	 111994 	 112004 	 DATE
#
#  Almost half 	 112005 	 112016 	 CARDINAL
#
#  March 2017 	 112151 	 112161 	 DATE
#
#  Mexican 	 112236 	 112243 	 NORP
#
#  U.S. 	 112279 	 112283 	 GPE
#
#  LA Times 	 112332 	 112340 	 ORG
#
#  RT 	 112342 	 112344 	 ORG
#
#  NBC 	 112346 	 112349 	 ORG
#
#  Daily Caller 	 112354 	 112366 	 PERSON
#
#  3/30/2017 	 112494 	 112503 	 DATE
#
#  3/29/2017 - Trump 	 112690 	 112707 	 CARDINAL
#
#  Obama-era 	 112732 	 112741 	 DATE
#
#  Reuters 	 112761 	 112768 	 ORG
#
#  3/28/2017 - U.S. 	 112896 	 112912 	 DATE
#
#  UN 	 112927 	 112929 	 ORG
#
#  NYTimes & Reuters 	 112986 	 113003 	 ORG
#
#  3/27/2017 - North Dakota 	 113131 	 113155 	 DATE
#
#  Associated Press 	 113208 	 113224 	 ORG
#
#  3/24/2017 - 1,800 	 113352 	 113369 	 DATE
#
#  NFL 	 113399 	 113402 	 ORG
#
#  UK Daily Mail 	 113422 	 113435 	 ORG
#
#  3/23/2017 	 113563 	 113572 	 QUANTITY
#
#  US 	 113596 	 113598 	 GPE
#
#  Tillerson 	 113606 	 113615 	 PERSON
#
#  3/22/2017 - U.S. 	 113801 	 113817 	 DATE
#
#  10 	 113854 	 113856 	 CARDINAL
#
#  Reuters 	 113868 	 113875 	 ORG
#
#  3/21/2017 - 	 114003 	 114014 	 DATE
#
#  1.1 million 	 114025 	 114036 	 CARDINAL
#
#  last year - CNBC 	 114088 	 114104 	 DATE
#
#  3/20/2017 	 114232 	 114241 	 CARDINAL
#
#  123 	 114397 	 114400 	 CARDINAL
#
#  2020 	 114636 	 114640 	 DATE
#
#  Student News Daily         Launched 	 114641 	 114676 	 ORG
#
#  2005 	 114680 	 114684 	 DATE
#
#  StudentNewsDaily.com 	 114686 	 114706 	 ORG
#
#  501(c)3 	 114712 	 114719 	 CARDINAL
